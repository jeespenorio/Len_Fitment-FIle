# %%
import pandas as pd

#init data
data1 = {
    'Make': ['ARCTIC CAT'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['FRONT TRACK'],
    
    'MPN': ['LS4-11000F'],
    
    'AD LIST NUMBER': ['1121001'],
    
    
}


#list all models
list_models = [




'ZR 7000 LXR 129', 'ZR 7000 LXR 137', 'ZR 7000 Sno Pro 129', 'ZR 7000 Sno Pro 137', 'ZR 7000 Limited 129', 'ZR 7000 Limited 137', 'ZR 7000 El Tigre', 'ZR 7000 RR', 'ZR 7000 129', 'ZR 7000 137', 'ZR 7000 Limited 137 iACT'




]

#Range of Years
years = list(range(2016, 2024))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#           Make                     Model Vendor Code  \
# 0   ARCTIC CAT           ZR 7000 LXR 129        NACH
# 1   ARCTIC CAT           ZR 7000 LXR 137        NACH
# 2   ARCTIC CAT       ZR 7000 Sno Pro 129        NACH
# 3   ARCTIC CAT       ZR 7000 Sno Pro 137        NACH
# 4   ARCTIC CAT       ZR 7000 Limited 129        NACH
# ..         ...                       ...         ...
# 83  ARCTIC CAT          ZR 7000 El Tigre        NACH
# 84  ARCTIC CAT                ZR 7000 RR        NACH
# 85  ARCTIC CAT               ZR 7000 129        NACH
# 86  ARCTIC CAT               ZR 7000 137        NACH
# 87  ARCTIC CAT  ZR 7000 Limited 137 iACT        NACH
#
#                       Vendor Name     Position         MPN AD LIST NUMBER  \
# 0   NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 1   NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 2   NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 3   NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 4   NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# ..                            ...          ...         ...            ...
# 83  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 84  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 85  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 86  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 87  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
#
#     Year
# 0   2016
# 1   2016
# 2   2016
# 3   2016
# 4   2016
# ..   ...
# 83  2023
# 84  2023
# 85  2023
# 86  2023
# 87  2023
#
# [88 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\2.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['ARCTIC CAT'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['FRONT TRACK'],
    
    'MPN': ['LS4-11000F'],
    
    'AD LIST NUMBER': ['1121001'],
    
    
}


#list all models
list_models = [




'Riot 8000 1.6in.'





]

#Range of Years
years = list(range(2020, 2024))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#          Make             Model Vendor Code                    Vendor Name  \
# 0  ARCTIC CAT  Riot 8000 1.6in.        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1  ARCTIC CAT  Riot 8000 1.6in.        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2  ARCTIC CAT  Riot 8000 1.6in.        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3  ARCTIC CAT  Riot 8000 1.6in.        NACH  NACHMAN INTERNATIONAL CO. LTD
#
#       Position         MPN AD LIST NUMBER  Year
# 0  FRONT TRACK  LS4-11000F        1121001  2020
# 1  FRONT TRACK  LS4-11000F        1121001  2021
# 2  FRONT TRACK  LS4-11000F        1121001  2022
# 3  FRONT TRACK  LS4-11000F        1121001  2023

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\3.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['ARCTIC CAT'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['FRONT TRACK'],
    
    'MPN': ['LS4-11000F'],
    
    'AD LIST NUMBER': ['1121001'],
    
    
}


#list all models
list_models = [




'ProClimb M 800 HCR'





]

#Range of Years
years = list(range(2012, 2014))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#          Make               Model Vendor Code                    Vendor Name  \
# 0  ARCTIC CAT  ProClimb M 800 HCR        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1  ARCTIC CAT  ProClimb M 800 HCR        NACH  NACHMAN INTERNATIONAL CO. LTD
#
#       Position         MPN AD LIST NUMBER  Year
# 0  FRONT TRACK  LS4-11000F        1121001  2012
# 1  FRONT TRACK  LS4-11000F        1121001  2013

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\1.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['ARCTIC CAT'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['FRONT TRACK'],
    
    'MPN': ['LS4-11000F'],
    
    'AD LIST NUMBER': ['1121001'],
    
    
}


#list all models
list_models = [




'Pantera 6000 ES'





]

#Range of Years
years = list(range(2015, 2020))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#          Make            Model Vendor Code                    Vendor Name  \
# 0  ARCTIC CAT  Pantera 6000 ES        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1  ARCTIC CAT  Pantera 6000 ES        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2  ARCTIC CAT  Pantera 6000 ES        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3  ARCTIC CAT  Pantera 6000 ES        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4  ARCTIC CAT  Pantera 6000 ES        NACH  NACHMAN INTERNATIONAL CO. LTD
#
#       Position         MPN AD LIST NUMBER  Year
# 0  FRONT TRACK  LS4-11000F        1121001  2015
# 1  FRONT TRACK  LS4-11000F        1121001  2016
# 2  FRONT TRACK  LS4-11000F        1121001  2017
# 3  FRONT TRACK  LS4-11000F        1121001  2018
# 4  FRONT TRACK  LS4-11000F        1121001  2019

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\4.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['ARCTIC CAT'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['FRONT TRACK'],
    
    'MPN': ['LS4-11000F'],
    
    'AD LIST NUMBER': ['1121001'],
    
    
}


#list all models
list_models = [

'Riot 8000 1.6in.',
'Riot 8000 1.35in.',
'Riot 8000 ATAC 1.6in.',
'Riot 8000 ATAC',
'Riot 8000'


]

#Range of Years
years = list(range(2020, 2024))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#           Make                  Model Vendor Code  \
# 0   ARCTIC CAT       Riot 8000 1.6in.        NACH
# 1   ARCTIC CAT      Riot 8000 1.35in.        NACH
# 2   ARCTIC CAT  Riot 8000 ATAC 1.6in.        NACH
# 3   ARCTIC CAT         Riot 8000 ATAC        NACH
# 4   ARCTIC CAT              Riot 8000        NACH
# 5   ARCTIC CAT       Riot 8000 1.6in.        NACH
# 6   ARCTIC CAT      Riot 8000 1.35in.        NACH
# 7   ARCTIC CAT  Riot 8000 ATAC 1.6in.        NACH
# 8   ARCTIC CAT         Riot 8000 ATAC        NACH
# 9   ARCTIC CAT              Riot 8000        NACH
# 10  ARCTIC CAT       Riot 8000 1.6in.        NACH
# 11  ARCTIC CAT      Riot 8000 1.35in.        NACH
# 12  ARCTIC CAT  Riot 8000 ATAC 1.6in.        NACH
# 13  ARCTIC CAT         Riot 8000 ATAC        NACH
# 14  ARCTIC CAT              Riot 8000        NACH
# 15  ARCTIC CAT       Riot 8000 1.6in.        NACH
# 16  ARCTIC CAT      Riot 8000 1.35in.        NACH
# 17  ARCTIC CAT  Riot 8000 ATAC 1.6in.        NACH
# 18  ARCTIC CAT         Riot 8000 ATAC        NACH
# 19  ARCTIC CAT              Riot 8000        NACH
#
#                       Vendor Name     Position         MPN AD LIST NUMBER  \
# 0   NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 1   NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 2   NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 3   NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 4   NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 5   NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 6   NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 7   NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 8   NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 9   NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 10  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 11  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 12  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 13  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 14  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 15  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 16  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 17  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 18  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 19  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
#
#     Year
# 0   2020
# 1   2020
# 2   2020
# 3   2020
# 4   2020
# 5   2021
# 6   2021
# 7   2021
# 8   2021
# 9   2021
# 10  2022
# 11  2022
# 12  2022
# 13  2022
# 14  2022
# 15  2023
# 16  2023
# 17  2023
# 18  2023
# 19  2023

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\5.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['ARCTIC CAT'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['FRONT TRACK'],
    
    'MPN': ['LS4-11000F'],
    
    'AD LIST NUMBER': ['1121001'],
    
    
}


#list all models
list_models = [

'ZR 9000 LXR',
'ZR 9000 Sno Pro 129',
'ZR 9000 Sno Pro 137',
'ZR 9000 Limited 129',
'ZR 9000 Limited 137',
'ZR 9000 El Tigre',
'ZR 9000 RR',
'ZR 9000 RR 129',
'ZR 9000 RR 137',
'ZR 9000 Thundercat',
'ZR 9000 Thundercat iACT',
'ZR 9000 Limited',
'ZR 9000 Limited iACT',
'ZR 9000 Thundercat ATAC',
'ZR 9000 Thundercat EPS',
'ZR 9000 Thundercat EPS ATAC'



]

#Range of Years
years = list(range(2016, 2024))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#            Make                        Model Vendor Code  \
# 0    ARCTIC CAT                  ZR 9000 LXR        NACH
# 1    ARCTIC CAT          ZR 9000 Sno Pro 129        NACH
# 2    ARCTIC CAT          ZR 9000 Sno Pro 137        NACH
# 3    ARCTIC CAT          ZR 9000 Limited 129        NACH
# 4    ARCTIC CAT          ZR 9000 Limited 137        NACH
# ..          ...                          ...         ...
# 123  ARCTIC CAT              ZR 9000 Limited        NACH
# 124  ARCTIC CAT         ZR 9000 Limited iACT        NACH
# 125  ARCTIC CAT      ZR 9000 Thundercat ATAC        NACH
# 126  ARCTIC CAT       ZR 9000 Thundercat EPS        NACH
# 127  ARCTIC CAT  ZR 9000 Thundercat EPS ATAC        NACH
#
#                        Vendor Name     Position         MPN AD LIST NUMBER  \
# 0    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 1    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 2    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 3    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 4    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# ..                             ...          ...         ...            ...
# 123  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 124  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 125  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 126  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 127  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
#
#      Year
# 0    2016
# 1    2016
# 2    2016
# 3    2016
# 4    2016
# ..    ...
# 123  2023
# 124  2023
# 125  2023
# 126  2023
# 127  2023
#
# [128 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\6.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['ARCTIC CAT'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['REAR TRACK'],
    
    'MPN': ['LS4-110004'],
    
    'AD LIST NUMBER': ['1121002'],
    
    
}


#list all models
list_models = [

'XF 6000 Crosstrek', 'XF 6000 High Country', 'XF 6000 Cross Country Limited ES', 'XF 6000 Crosstrek ES', 'XF 6000 High Country Limited ES', 'XF 6000 High Country ES', 'XF 6000 Crosstour ES', 'XF 7000 Crosstrek', 'XF 7000 High Country', 'XF 7000 Crosstour', 'XF 8000 Crosstrek', 'XF 8000 High Country', 'XF 8000 High Country Limited', 'XF 8000 Crosstrek ES', 'XF 8000 Cross Country Limited ES', 'XF 8000 High Country Limited ES 141', 'XF 8000 High Country Limited ES 153', 'XF 9000 Crosstrek', 'XF 9000 High Country Limited', 'XF 9000 Cross Country Limited', 'XF 9000 High Country Limited 141', 'XF 9000 High Country Limited 153', 'XF 9000 Crosstour'


]

#Range of Years
years = list(range(2016, 2024))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#            Make                             Model Vendor Code  \
# 0    ARCTIC CAT                 XF 6000 Crosstrek        NACH
# 1    ARCTIC CAT              XF 6000 High Country        NACH
# 2    ARCTIC CAT  XF 6000 Cross Country Limited ES        NACH
# 3    ARCTIC CAT              XF 6000 Crosstrek ES        NACH
# 4    ARCTIC CAT   XF 6000 High Country Limited ES        NACH
# ..          ...                               ...         ...
# 110  ARCTIC CAT      XF 9000 High Country Limited        NACH
# 111  ARCTIC CAT     XF 9000 Cross Country Limited        NACH
# 112  ARCTIC CAT  XF 9000 High Country Limited 141        NACH
# 113  ARCTIC CAT  XF 9000 High Country Limited 153        NACH
# 114  ARCTIC CAT                 XF 9000 Crosstour        NACH
#
#                        Vendor Name    Position         MPN AD LIST NUMBER  \
# 0    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-110004        1121002
# 1    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-110004        1121002
# 2    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-110004        1121002
# 3    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-110004        1121002
# 4    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-110004        1121002
# ..                             ...         ...         ...            ...
# 110  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-110004        1121002
# 111  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-110004        1121002
# 112  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-110004        1121002
# 113  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-110004        1121002
# 114  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-110004        1121002
#
#      Year
# 0    2014
# 1    2014
# 2    2014
# 3    2014
# 4    2014
# ..    ...
# 110  2018
# 111  2018
# 112  2018
# 113  2018
# 114  2018
#
# [115 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\7.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['POLARIS'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['FRONT TRACK'],
    
    'MPN': ['LS4-50000F'],
    
    'AD LIST NUMBER': ['1121003'],
    
    
}


#list all models
list_models = [

    
'600 SwitchBack Assault 144',
'600 SwitchBack',
'600 Dragon SwitchBack',
'600 HO CFI SwitchBack',
'600 SwitchBack Adventure',
'600 SwitchBack PRO-R',
'600 SwitchBack PRO-S',
'600 SwitchBack SP 144',
'600 SwitchBack XCR',
'650 SwitchBack Assault 146',
'650 SwitchBack XC 146',
'650 SwitchBack SP 146',
'800 Rush PRO-R',
'800 Rush',
'800 Rush PRO-R LE',
'800 Rush PRO-X',
'800 Rush PRO-S',
'800 Rush PRO-S LE',
'800 Rush XCR',
'800 SKS',
'800 SKS 155',
'800 SKS 146',
'800 SwitchBack',
'800 SwitchBack Assault 144',
'800 SwitchBack PRO-R',
'800 SwitchBack Adventure',
'800 SwitchBack PRO-R LE',
'800 SwitchBack Assault LE',
'800 SwitchBack PRO-X',
'800 SwitchBack PRO-S',
'800 SwitchBack Assault 144 TD Series LE',
'800 SwitchBack PRO-S LE',
'800 SwitchBack XCR',
'850 SwitchBack Assault 144',
'850 SwitchBack PRO-S',
'850 SwitchBack XCR',
'850 SwitchBack Assault 146',
'850 SwitchBack XC 146',
'850 SKS 155',
'850 SKS 146'


]

#Range of Years
years = list(range(2012, 2022))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                       Model Vendor Code  \
# 0    POLARIS  600 SwitchBack Assault 144        NACH
# 1    POLARIS              600 SwitchBack        NACH
# 2    POLARIS       600 Dragon SwitchBack        NACH
# 3    POLARIS       600 HO CFI SwitchBack        NACH
# 4    POLARIS    600 SwitchBack Adventure        NACH
# ..       ...                         ...         ...
# 395  POLARIS          850 SwitchBack XCR        NACH
# 396  POLARIS  850 SwitchBack Assault 146        NACH
# 397  POLARIS       850 SwitchBack XC 146        NACH
# 398  POLARIS                 850 SKS 155        NACH
# 399  POLARIS                 850 SKS 146        NACH
#
#                        Vendor Name     Position         MPN AD LIST NUMBER  \
# 0    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-50000F        1121003
# 1    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-50000F        1121003
# 2    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-50000F        1121003
# 3    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-50000F        1121003
# 4    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-50000F        1121003
# ..                             ...          ...         ...            ...
# 395  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-50000F        1121003
# 396  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-50000F        1121003
# 397  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-50000F        1121003
# 398  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-50000F        1121003
# 399  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-50000F        1121003
#
#      Year
# 0    2012
# 1    2012
# 2    2012
# 3    2012
# 4    2012
# ..    ...
# 395  2021
# 396  2021
# 397  2021
# 398  2021
# 399  2021
#
# [400 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\9.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['POLARIS'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['REAR TRACK'],
    
    'MPN': ['LS4-50000R'],
    
    'AD LIST NUMBER': ['1121004'],
    
    
}


#list all models
list_models = [

    '600 SwitchBack Assault 144',
'600 SwitchBack',
'600 Dragon SwitchBack',
'600 HO CFI SwitchBack',
'600 SwitchBack Adventure',
'600 SwitchBack PRO-R',
'600 SwitchBack PRO-S',
'600 SwitchBack SP 144',
'600 SwitchBack XCR',
'650 SwitchBack Assault 146',
'650 SwitchBack XC 146',
'650 SwitchBack SP 146',
'800 Rush PRO-R',
'800 Rush',
'800 Rush PRO-R LE',
'800 Rush PRO-X',
'800 Rush PRO-S',
'800 Rush PRO-S LE',
'800 Rush XCR',
'800 SKS',
'800 SKS 155',
'800 SKS 146',
'800 SwitchBack',
'800 SwitchBack Assault 144',
'800 SwitchBack PRO-R',
'800 SwitchBack Adventure',
'800 SwitchBack PRO-R LE',
'800 SwitchBack Assault LE',
'800 SwitchBack PRO-X',
'800 SwitchBack PRO-S',
'800 SwitchBack Assault 144 TD Series LE',
'800 SwitchBack PRO-S LE',
'800 SwitchBack XCR',
'850 SwitchBack Assault 144',
'850 SwitchBack PRO-S',
'850 SwitchBack XCR',
'850 SwitchBack Assault 146',
'850 SwitchBack XC 146',
'850 SKS 155',
'850 SKS 146'


]

#Range of Years
years = list(range(2017, 2022))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                       Model Vendor Code  \
# 0    POLARIS  600 SwitchBack Assault 144        NACH
# 1    POLARIS              600 SwitchBack        NACH
# 2    POLARIS       600 Dragon SwitchBack        NACH
# 3    POLARIS       600 HO CFI SwitchBack        NACH
# 4    POLARIS    600 SwitchBack Adventure        NACH
# ..       ...                         ...         ...
# 195  POLARIS          850 SwitchBack XCR        NACH
# 196  POLARIS  850 SwitchBack Assault 146        NACH
# 197  POLARIS       850 SwitchBack XC 146        NACH
# 198  POLARIS                 850 SKS 155        NACH
# 199  POLARIS                 850 SKS 146        NACH
#
#                        Vendor Name    Position         MPN AD LIST NUMBER  \
# 0    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50000R        1121004
# 1    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50000R        1121004
# 2    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50000R        1121004
# 3    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50000R        1121004
# 4    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50000R        1121004
# ..                             ...         ...         ...            ...
# 195  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50000R        1121004
# 196  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50000R        1121004
# 197  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50000R        1121004
# 198  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50000R        1121004
# 199  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50000R        1121004
#
#      Year
# 0    2017
# 1    2017
# 2    2017
# 3    2017
# 4    2017
# ..    ...
# 195  2021
# 196  2021
# 197  2021
# 198  2021
# 199  2021
#
# [200 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\10.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['POLARIS'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['REAR TRACK'],
    
    'MPN': ['LS4-50000R'],
    
    'AD LIST NUMBER': ['1121004'],
    
    
}


#list all models
list_models = [

'600 SwitchBack Assault 144',
'600 SwitchBack',
'600 Dragon SwitchBack',
'600 HO CFI SwitchBack',
'600 SwitchBack Adventure',
'600 SwitchBack PRO-R',
'600 SwitchBack PRO-S',
'600 SwitchBack SP 144',
'600 SwitchBack XCR',
'650 SwitchBack Assault 146',
'650 SwitchBack XC 146',
'650 SwitchBack SP 146',
'800 Rush PRO-R',
'800 Rush',
'800 Rush PRO-R LE',
'800 Rush PRO-X',
'800 Rush PRO-S',
'800 Rush PRO-S LE',
'800 Rush XCR',
'800 SKS',
'800 SKS 155',
'800 SKS 146',
'800 SwitchBack',
'800 SwitchBack Assault 144',
'800 SwitchBack PRO-R',
'800 SwitchBack Adventure',
'800 SwitchBack PRO-R LE',
'800 SwitchBack Assault LE',
'800 SwitchBack PRO-X',
'800 SwitchBack PRO-S',
'800 SwitchBack Assault 144 TD Series LE',
'800 SwitchBack PRO-S LE',
'800 SwitchBack XCR',
'850 SwitchBack Assault 144',
'850 SwitchBack PRO-S',
'850 SwitchBack XCR',
'850 SwitchBack Assault 146',
'850 SwitchBack XC 146',
'850 SKS 155',
'850 SKS 146'


]

#Range of Years
years = list(range(2017, 2022))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                       Model Vendor Code  \
# 0    POLARIS  600 SwitchBack Assault 144        NACH
# 1    POLARIS              600 SwitchBack        NACH
# 2    POLARIS       600 Dragon SwitchBack        NACH
# 3    POLARIS       600 HO CFI SwitchBack        NACH
# 4    POLARIS    600 SwitchBack Adventure        NACH
# ..       ...                         ...         ...
# 195  POLARIS          850 SwitchBack XCR        NACH
# 196  POLARIS  850 SwitchBack Assault 146        NACH
# 197  POLARIS       850 SwitchBack XC 146        NACH
# 198  POLARIS                 850 SKS 155        NACH
# 199  POLARIS                 850 SKS 146        NACH
#
#                        Vendor Name    Position         MPN AD LIST NUMBER  \
# 0    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50000R        1121004
# 1    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50000R        1121004
# 2    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50000R        1121004
# 3    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50000R        1121004
# 4    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50000R        1121004
# ..                             ...         ...         ...            ...
# 195  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50000R        1121004
# 196  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50000R        1121004
# 197  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50000R        1121004
# 198  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50000R        1121004
# 199  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50000R        1121004
#
#      Year
# 0    2017
# 1    2017
# 2    2017
# 3    2017
# 4    2017
# ..    ...
# 195  2021
# 196  2021
# 197  2021
# 198  2021
# 199  2021
#
# [200 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\11.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['POLARIS'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['REAR TRACK'],
    
    'MPN': ['LS4-50001R'],
    
    'AD LIST NUMBER': ['1121005'],
    
    
}


#list all models
list_models = [

'600 SwitchBack Assault 144',
'600 SwitchBack',
'600 Dragon SwitchBack',
'600 HO CFI SwitchBack',
'600 SwitchBack Adventure',
'600 SwitchBack PRO-R',
'600 SwitchBack PRO-S',
'600 SwitchBack SP 144',
'600 SwitchBack XCR',
'800 SwitchBack PRO-R LE',
'800 SwitchBack Assault LE',
'800 SwitchBack PRO-S LE'


]

#Range of Years
years = list(range(2012, 2018))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make                       Model Vendor Code  \
# 0   POLARIS  600 SwitchBack Assault 144        NACH
# 1   POLARIS              600 SwitchBack        NACH
# 2   POLARIS       600 Dragon SwitchBack        NACH
# 3   POLARIS       600 HO CFI SwitchBack        NACH
# 4   POLARIS    600 SwitchBack Adventure        NACH
# ..      ...                         ...         ...
# 67  POLARIS       600 SwitchBack SP 144        NACH
# 68  POLARIS          600 SwitchBack XCR        NACH
# 69  POLARIS     800 SwitchBack PRO-R LE        NACH
# 70  POLARIS   800 SwitchBack Assault LE        NACH
# 71  POLARIS     800 SwitchBack PRO-S LE        NACH
#
#                       Vendor Name    Position         MPN AD LIST NUMBER  Year
# 0   NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50001R        1121005  2012
# 1   NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50001R        1121005  2012
# 2   NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50001R        1121005  2012
# 3   NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50001R        1121005  2012
# 4   NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50001R        1121005  2012
# ..                            ...         ...         ...            ...   ...
# 67  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50001R        1121005  2017
# 68  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50001R        1121005  2017
# 69  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50001R        1121005  2017
# 70  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50001R        1121005  2017
# 71  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-50001R        1121005  2017
#
# [72 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\12.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['POLARIS'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['FRONT TRACK'],
    
    'MPN': ['LS4-80000F'],
    
    'AD LIST NUMBER': ['1121006'],
    
    
}


#list all models
list_models = [

'Freeride E-TEC 800R 137',
'Freeride E-TEC 800R 146',
'Freeride E-TEC 800R 154',
'Freeride E-TEC 850 137',
'Freeride E-TEC 850 146',
'Freeride E-TEC 850 154',
'Freeride E-TEC 850 165',
'Freeride E-TEC 850 Turbo 154',
'Freeride E-TEC 850 Turbo 165',
'Freeride E-TEC 850 Turbo 146',
'Renegade 600 Backcountry',
'Renegade 600 Adrenaline',
'Renegade 600 X',
'Renegade 800 Backcountry',
'Renegade 800 Adrenaline',
'Renegade 800 Backcountry X',
'Renegade 800 X',
'Summit 600',
'Summit 600 R Sport',
'Summit 600 Sport',
'Summit 600 Adrenaline',
'Summit 600 X',
'Summit 600 X 154',
'Summit 600 Everest 146',
'Summit 600 Everest',
'Summit 800 R Everest',
'Summit 800 X 144',
'Summit 800 XRS 151',
'Summit 800 X',
'Summit 800 Highmark',
'Summit 800 Highmark X',
'Summit 800 Foothill',
'Summit 800',
'Summit 800 Sport',
'Summit 800 R Sport',
'Summit 800 R X',
'Summit 800 R Highmark X',
'Summit 800 R Highmark',
'Summit 800 Adrenaline 144',
'Summit 800 Highmark Xtreme',
'Summit 800 Adrenaline 151',
'Summit 800 X 163',
'Summit 800 X 154',
'Summit 800 Hill Climb',
'Summit 800 Everest 163',
'Summit 800 Everest 154',
'Summit 800 Everest 146',
'Summit 800 X 146',
'Summit 800 XRS 159',
'Summit 800 X 151',
'Summit 800 X 159',
'Summit 800 R 50th Anniversary',
'Summit X E-TEC 850 154',
'Summit X E-TEC 850 165',
'Summit SP E-TEC 850 154',
'Summit SP E-TEC 850 165',
'Summit X E-TEC 850 175',
'Summit SP E-TEC 850 146',
'Summit SP E-TEC 850 175',
'Summit X with Expert Package E-TEC 850 154',
'Summit X with Expert Package E-TEC 850 165',
'Summit X E-TEC 850 Turbo 154',
'Summit X E-TEC 850 Turbo 165',
'Summit X with Expert Package E-TEC 850 175',
'Summit X with Expert Package E-TEC 850 Turbo 154',
'Summit X with Expert Package E-TEC 850 Turbo 165',
'Summit X with Expert Package E-TEC 850 Turbo 175',
'Summit X w/ Expert Package E-TEC 850 Turbo 154 2.5',
'Summit Edge E-TEC 850 175',
'Summit Edge E-TEC 850 154',
'Summit X with Expert Package E-TEC 850 154 2.5',
'Summit Edge E-TEC 850 165',
'Summit X E-TEC 850 Turbo R 154',
'Summit X E-TEC 850 Turbo R 165',
'Summit X with Expert Package E-TEC 850 Turbo R 154',
'Summit X with Expert Package E-TEC 850 Turbo R 165',
'Summit X with Expert Package E-TEC 850 Turbo R 175'


]

#Range of Years
years = list(range(2015, 2024))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                                              Model Vendor Code  \
# 0    POLARIS                            Freeride E-TEC 800R 137        NACH
# 1    POLARIS                            Freeride E-TEC 800R 146        NACH
# 2    POLARIS                            Freeride E-TEC 800R 154        NACH
# 3    POLARIS                             Freeride E-TEC 850 137        NACH
# 4    POLARIS                             Freeride E-TEC 850 146        NACH
# ..       ...                                                ...         ...
# 688  POLARIS                     Summit X E-TEC 850 Turbo R 154        NACH
# 689  POLARIS                     Summit X E-TEC 850 Turbo R 165        NACH
# 690  POLARIS  Summit X with Expert Package E-TEC 850 Turbo R...        NACH
# 691  POLARIS  Summit X with Expert Package E-TEC 850 Turbo R...        NACH
# 692  POLARIS  Summit X with Expert Package E-TEC 850 Turbo R...        NACH
#
#                        Vendor Name     Position         MPN AD LIST NUMBER  \
# 0    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-80000F        1121006
# 1    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-80000F        1121006
# 2    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-80000F        1121006
# 3    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-80000F        1121006
# 4    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-80000F        1121006
# ..                             ...          ...         ...            ...
# 688  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-80000F        1121006
# 689  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-80000F        1121006
# 690  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-80000F        1121006
# 691  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-80000F        1121006
# 692  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-80000F        1121006
#
#      Year
# 0    2015
# 1    2015
# 2    2015
# 3    2015
# 4    2015
# ..    ...
# 688  2023
# 689  2023
# 690  2023
# 691  2023
# 692  2023
#
# [693 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\13.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['POLARIS'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['REAR TRACK'],
    
    'MPN': ['LS4-80000R'],
    
    'AD LIST NUMBER': ['1121007'],
    
    
}


#list all models
list_models = [

'Freeride E-TEC 800R 137',
'Freeride E-TEC 800R 146',
'Freeride E-TEC 800R 154',
'Freeride E-TEC 850 137',
'Freeride E-TEC 850 146',
'Freeride E-TEC 850 154',
'Freeride E-TEC 850 165',
'Freeride E-TEC 850 Turbo 154',
'Freeride E-TEC 850 Turbo 165',
'Freeride E-TEC 850 Turbo 146',
'Renegade 600 Backcountry',
'Renegade 600 Adrenaline',
'Renegade 600 X',
'Renegade 800 Backcountry',
'Renegade 800 Adrenaline',
'Renegade 800 Backcountry X',
'Renegade 800 X',
'Summit 600',
'Summit 600 R Sport',
'Summit 600 Sport',
'Summit 600 Adrenaline',
'Summit 600 X',
'Summit 600 X 154',
'Summit 600 Everest 146',
'Summit 600 Everest',
'Summit 800 R Everest',
'Summit 800 X 144',
'Summit 800 XRS 151',
'Summit 800 X',
'Summit 800 Highmark',
'Summit 800 Highmark X',
'Summit 800 Foothill',
'Summit 800',
'Summit 800 Sport',
'Summit 800 R Sport',
'Summit 800 R X',
'Summit 800 R Highmark X',
'Summit 800 R Highmark',
'Summit 800 Adrenaline 144',
'Summit 800 Highmark Xtreme',
'Summit 800 Adrenaline 151',
'Summit 800 X 163',
'Summit 800 X 154',
'Summit 800 Hill Climb',
'Summit 800 Everest 163',
'Summit 800 Everest 154',
'Summit 800 Everest 146',
'Summit 800 X 146',
'Summit 800 XRS 159',
'Summit 800 X 151',
'Summit 800 X 159',
'Summit 800 R 50th Anniversary',
'Summit X E-TEC 850 154',
'Summit X E-TEC 850 165',
'Summit SP E-TEC 850 154',
'Summit SP E-TEC 850 165',
'Summit X E-TEC 850 175',
'Summit SP E-TEC 850 146',
'Summit SP E-TEC 850 175',
'Summit X with Expert Package E-TEC 850 154',
'Summit X with Expert Package E-TEC 850 165',
'Summit X E-TEC 850 Turbo 154',
'Summit X E-TEC 850 Turbo 165',
'Summit X with Expert Package E-TEC 850 175',
'Summit X with Expert Package E-TEC 850 Turbo 154',
'Summit X with Expert Package E-TEC 850 Turbo 165',
'Summit X with Expert Package E-TEC 850 Turbo 175',
'Summit X w/ Expert Package E-TEC 850 Turbo 154 2.5',
'Summit Edge E-TEC 850 175',
'Summit Edge E-TEC 850 154',
'Summit X with Expert Package E-TEC 850 154 2.5',
'Summit Edge E-TEC 850 165',
'Summit X E-TEC 850 Turbo R 154',
'Summit X E-TEC 850 Turbo R 165',
'Summit X with Expert Package E-TEC 850 Turbo R 154',
'Summit X with Expert Package E-TEC 850 Turbo R 165',
'Summit X with Expert Package E-TEC 850 Turbo R 175'


]

#Range of Years
years = list(range(2015, 2024))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                                              Model Vendor Code  \
# 0    POLARIS                            Freeride E-TEC 800R 137        NACH
# 1    POLARIS                            Freeride E-TEC 800R 146        NACH
# 2    POLARIS                            Freeride E-TEC 800R 154        NACH
# 3    POLARIS                             Freeride E-TEC 850 137        NACH
# 4    POLARIS                             Freeride E-TEC 850 146        NACH
# ..       ...                                                ...         ...
# 688  POLARIS                     Summit X E-TEC 850 Turbo R 154        NACH
# 689  POLARIS                     Summit X E-TEC 850 Turbo R 165        NACH
# 690  POLARIS  Summit X with Expert Package E-TEC 850 Turbo R...        NACH
# 691  POLARIS  Summit X with Expert Package E-TEC 850 Turbo R...        NACH
# 692  POLARIS  Summit X with Expert Package E-TEC 850 Turbo R...        NACH
#
#                        Vendor Name    Position         MPN AD LIST NUMBER  \
# 0    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-80000R        1121007
# 1    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-80000R        1121007
# 2    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-80000R        1121007
# 3    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-80000R        1121007
# 4    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-80000R        1121007
# ..                             ...         ...         ...            ...
# 688  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-80000R        1121007
# 689  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-80000R        1121007
# 690  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-80000R        1121007
# 691  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-80000R        1121007
# 692  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-80000R        1121007
#
#      Year
# 0    2015
# 1    2015
# 2    2015
# 3    2015
# 4    2015
# ..    ...
# 688  2023
# 689  2023
# 690  2023
# 691  2023
# 692  2023
#
# [693 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\14.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['SKI-DOO'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['FRONT TRACK'],
    
    'MPN': ['LS4-80001F'],
    
    'AD LIST NUMBER': ['1121008'],
    
    
}


#list all models
list_models = [

'MX Z Blizzard E-TEC 600 HO',
'MX Z Blizzard E-TEC 800R',
'MX Z Blizzard ACE 900',
'MX Z Blizzard 4-TEC 1200',
'MX Z Blizzard E-TEC 850',
'MX Z Blizzard E-TEC 600R',
'MX Z TNT 800R Power TEC',
'MX Z TNT E-TEC 600 HO',
'MX Z TNT 600 ACE',
'MX Z TNT E-TEC 800R',
'MX Z TNT 4-TEC 1200',
'MX Z TNT 600 Carb',
'MX Z TNT ACE 900',
'MX Z TNT E-TEC 850',
'MX Z TNT E-TEC 600R',
'MX Z X-RS E-TEC 800R',
'MX Z X-RS 800R',
'MX Z X E-TEC 800R',
'MX Z X-RS E-TEC 600 HO',
'MX Z X 4-TEC 1200',
'MX Z X E-TEC 600 HO',
'MX Z X-RS 600',
'MX Z X E-TEC 850',
'MX Z X-RS Iron Dog E-TEC 600 HO',
'MX Z X-RS E-TEC 850',
'MX Z X E-TEC 600R',
'MX Z X-RS E-TEC 600R'

]

#Range of Years
years = list(range(2015, 2024))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                            Model Vendor Code  \
# 0    SKI-DOO       MX Z Blizzard E-TEC 600 HO        NACH
# 1    SKI-DOO         MX Z Blizzard E-TEC 800R        NACH
# 2    SKI-DOO            MX Z Blizzard ACE 900        NACH
# 3    SKI-DOO         MX Z Blizzard 4-TEC 1200        NACH
# 4    SKI-DOO          MX Z Blizzard E-TEC 850        NACH
# ..       ...                              ...         ...
# 238  SKI-DOO                 MX Z X E-TEC 850        NACH
# 239  SKI-DOO  MX Z X-RS Iron Dog E-TEC 600 HO        NACH
# 240  SKI-DOO              MX Z X-RS E-TEC 850        NACH
# 241  SKI-DOO                MX Z X E-TEC 600R        NACH
# 242  SKI-DOO             MX Z X-RS E-TEC 600R        NACH
#
#                        Vendor Name     Position         MPN AD LIST NUMBER  \
# 0    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-80001F        1121008
# 1    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-80001F        1121008
# 2    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-80001F        1121008
# 3    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-80001F        1121008
# 4    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-80001F        1121008
# ..                             ...          ...         ...            ...
# 238  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-80001F        1121008
# 239  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-80001F        1121008
# 240  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-80001F        1121008
# 241  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-80001F        1121008
# 242  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-80001F        1121008
#
#      Year
# 0    2015
# 1    2015
# 2    2015
# 3    2015
# 4    2015
# ..    ...
# 238  2023
# 239  2023
# 240  2023
# 241  2023
# 242  2023
#
# [243 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\15.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['SKI-DOO'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['REAR TRACK'],
    
    'MPN': ['LS4-80001R'],
    
    'AD LIST NUMBER': ['1121009'],
    
    
}


#list all models
list_models = [

'MX Z Blizzard E-TEC 600 HO',
'MX Z Blizzard E-TEC 800R',
'MX Z Blizzard ACE 900',
'MX Z Blizzard 4-TEC 1200',
'MX Z Blizzard E-TEC 850',
'MX Z Blizzard E-TEC 600R',
'MX Z TNT 800R Power TEC',
'MX Z TNT E-TEC 600 HO',
'MX Z TNT 600 ACE',
'MX Z TNT E-TEC 800R',
'MX Z TNT 4-TEC 1200',
'MX Z TNT 600 Carb',
'MX Z TNT ACE 900',
'MX Z TNT E-TEC 850',
'MX Z TNT E-TEC 600R',
'MX Z X-RS E-TEC 800R',
'MX Z X-RS 800R',
'MX Z X E-TEC 800R',
'MX Z X-RS E-TEC 600 HO',
'MX Z X 4-TEC 1200',
'MX Z X E-TEC 600 HO',
'MX Z X-RS 600',
'MX Z X E-TEC 850',
'MX Z X-RS Iron Dog E-TEC 600 HO',
'MX Z X-RS E-TEC 850',
'MX Z X E-TEC 600R',
'MX Z X-RS E-TEC 600R'

]

#Range of Years
years = list(range(2021, 2024))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make                            Model Vendor Code  \
# 0   SKI-DOO       MX Z Blizzard E-TEC 600 HO        NACH
# 1   SKI-DOO         MX Z Blizzard E-TEC 800R        NACH
# 2   SKI-DOO            MX Z Blizzard ACE 900        NACH
# 3   SKI-DOO         MX Z Blizzard 4-TEC 1200        NACH
# 4   SKI-DOO          MX Z Blizzard E-TEC 850        NACH
# ..      ...                              ...         ...
# 76  SKI-DOO                 MX Z X E-TEC 850        NACH
# 77  SKI-DOO  MX Z X-RS Iron Dog E-TEC 600 HO        NACH
# 78  SKI-DOO              MX Z X-RS E-TEC 850        NACH
# 79  SKI-DOO                MX Z X E-TEC 600R        NACH
# 80  SKI-DOO             MX Z X-RS E-TEC 600R        NACH
#
#                       Vendor Name    Position         MPN AD LIST NUMBER  Year
# 0   NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-80001R        1121009  2021
# 1   NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-80001R        1121009  2021
# 2   NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-80001R        1121009  2021
# 3   NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-80001R        1121009  2021
# 4   NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-80001R        1121009  2021
# ..                            ...         ...         ...            ...   ...
# 76  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-80001R        1121009  2023
# 77  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-80001R        1121009  2023
# 78  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-80001R        1121009  2023
# 79  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-80001R        1121009  2023
# 80  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-80001R        1121009  2023
#
# [81 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\16.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['ARCTIC CAT'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['SKI'],
    
    'MPN': ['LS8-11000'],
    
    'AD LIST NUMBER': ['1121010'],
    
    
}


#list all models
list_models = [

    
'Pantera 3000',
'Riot 6000',
'Riot 6000 1.35in.',
'Pantera 7000 Limited',
'Pantera 7000',
'Pantera 7000 XT Limited',
'Pantera 6000 ES',
'ProClimb M 800 HCR',    
'ProCross F 800 Tucker Hibbert Race Replica',
'ProCross F 800 Sno Pro RR',
'ProCross F 800 Sno Pro Limited',
'ProCross F 800 Sno Pro',
'ProCross F 800 LXR',
'ProCross XF 1100 Turbo Sno Pro 50th',
'ProCross XF 1100 Turbo Sno Pro Limited',
'ProCross XF 1100 Turbo Sno Pro',
'ProCross XF 1100 Turbo LXR',
'ProCross XF 1100 Sno Pro 50th',
'ProCross XF 1100 Sno Pro Limited',
'ProCross XF 1100 Sno Pro',
'ProCross XF 1100 LXR',
'ProCross XF 1100 Turbo Crosstour',
'ProCross XF 1100 Crosstour',
'XF 8000 Sno Pro',
'XF 8000 LXR',
'XF 8000 Limited',
'XF 8000 High Country Limited',
'XF 8000 High Country',
'XF 8000 Crosstrek',
'XF 8000 Crosstour',
'XF 8000 Cross Country Sno Pro',
'XF 7000 LXR',
'XF 7000 Sno Pro',
'XF 7000 Limited',
'XF 7000 Crosstour',
'XF 7000 Cross Country Sno Pro',
'XF 8000 Cross Country Limited',
'XF 8000 Cross Country',
'XF 9000 High Country Limited',
'XF 9000 High Country Sno Pro',
'XF 9000 Crosstour',
'XF 9000 Cross Country Sno Pro',
'XF 9000 LXR',
'XF 9000 Sno Pro',
'XF 9000 Limited',
'XF 6000 LXR',
'XF 6000 Sno Pro',
'XF 6000 Limited',
'XF 6000 Crosstour',
'XF 6000 Cross Country',
'XF 6000 High Country',
'XF 7000 Cross Country',
'XF 7000 High Country',
'ProCross XF 800 Crosstour',
'XF 9000 Cross Country',
'XF 9000 High Country',
'XF 9000 Cross Country Limited',
'XF 6000 Crosstrek',
'XF 7000 Crosstrek',
'XF 9000 Crosstrek',
'ZR 5000 LXR',
'ZR 6000 El Tigre',
'ZR 6000 El Tigre ES',
'ZR 7000 LXR 129',
'ZR 7000 Sno Pro 129',
'ZR 7000 Limited 129',
'ZR 6000 RR',
'ZR 6000 LXR 129',
'ZR 6000 Sno Pro 129',
'ZR 6000 Limited 129',
'ZR 6000 Tucker Hibbert RR',
'ZR 7000 El Tigre',
'ZR 7000 RR',
'ZR 6000 LXR 137',
'ZR 6000 Sno Pro 137',
'ZR 6000 Limited 137',
'ZR 7000 LXR 137',
'ZR 7000 Sno Pro 137',
'ZR 7000 Limited 137'

]

#Range of Years
years = list(range(2012, 2022))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#            Make                 Model Vendor Code  \
# 0    ARCTIC CAT          Pantera 3000        NACH
# 1    ARCTIC CAT             Riot 6000        NACH
# 2    ARCTIC CAT     Riot 6000 1.35in.        NACH
# 3    ARCTIC CAT  Pantera 7000 Limited        NACH
# 4    ARCTIC CAT          Pantera 7000        NACH
# ..          ...                   ...         ...
# 785  ARCTIC CAT   ZR 6000 Sno Pro 137        NACH
# 786  ARCTIC CAT   ZR 6000 Limited 137        NACH
# 787  ARCTIC CAT       ZR 7000 LXR 137        NACH
# 788  ARCTIC CAT   ZR 7000 Sno Pro 137        NACH
# 789  ARCTIC CAT   ZR 7000 Limited 137        NACH
#
#                        Vendor Name Position        MPN AD LIST NUMBER  Year
# 0    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-11000        1121010  2012
# 1    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-11000        1121010  2012
# 2    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-11000        1121010  2012
# 3    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-11000        1121010  2012
# 4    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-11000        1121010  2012
# ..                             ...      ...        ...            ...   ...
# 785  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-11000        1121010  2021
# 786  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-11000        1121010  2021
# 787  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-11000        1121010  2021
# 788  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-11000        1121010  2021
# 789  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-11000        1121010  2021
#
# [790 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\17.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['POLARIS'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['SKI'],
    
    'MPN': ['LS8-50000'],
    
    'AD LIST NUMBER': ['1121011'],
    
    
}


#list all models
list_models = [



'600 INDY SP',
'600 INDY SP LE',
'600 INDY SP TD Series LE',
'600 INDY SP 129',
'600 INDY SP 137',
'600 SwitchBack Assault 144',
'600 SwitchBack SP 144',
'650 INDY Adventure 137',
'650 INDY Adventure X2 137',
'650 INDY VR1 137',
'650 INDY VR1 129',
'650 INDY XC Launch Edition 137',
'650 INDY XC Launch Edition 129',
'650 INDY XCR 136',
'650 INDY XCR 128',
'650 INDY XC 137',
'650 INDY XC 129',
'650 INDY SP 137',
'800 Rush PRO-X',
'800 SwitchBack Assault 144',
'800 SwitchBack Assault 144 TD Series LE',
'850 INDY XC 129',
'850 INDY XC 137',
'850 INDY XCR',
'850 INDY Adventure 137',
'850 INDY VR1 137',
'850 INDY VR1 129',
'850 INDY XC Launch Edition 137',
'850 INDY XC Launch Edition 129',
'850 INDY XCR 136',
'850 INDY XCR 128',
'Patriot Boost INDY VR1 129',
'Patriot Boost INDY VR1 137',
'Patriot Boost SwitchBack Assault 146'

]

#Range of Years
years = list(range(2017, 2024))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                                 Model Vendor Code  \
# 0    POLARIS                           600 INDY SP        NACH
# 1    POLARIS                        600 INDY SP LE        NACH
# 2    POLARIS              600 INDY SP TD Series LE        NACH
# 3    POLARIS                       600 INDY SP 129        NACH
# 4    POLARIS                       600 INDY SP 137        NACH
# ..       ...                                   ...         ...
# 233  POLARIS                      850 INDY XCR 136        NACH
# 234  POLARIS                      850 INDY XCR 128        NACH
# 235  POLARIS            Patriot Boost INDY VR1 129        NACH
# 236  POLARIS            Patriot Boost INDY VR1 137        NACH
# 237  POLARIS  Patriot Boost SwitchBack Assault 146        NACH
#
#                        Vendor Name Position        MPN AD LIST NUMBER  Year
# 0    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50000        1121011  2017
# 1    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50000        1121011  2017
# 2    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50000        1121011  2017
# 3    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50000        1121011  2017
# 4    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50000        1121011  2017
# ..                             ...      ...        ...            ...   ...
# 233  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50000        1121011  2023
# 234  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50000        1121011  2023
# 235  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50000        1121011  2023
# 236  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50000        1121011  2023
# 237  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50000        1121011  2023
#
# [238 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\18.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['POLARIS'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['SKI'],
    
    'MPN': ['LS8-50002'],
    
    'AD LIST NUMBER': ['1121012'],
    
    
}


#list all models
list_models = [


'600 PRO-RMK 155',
'800 PRO-RMK 163',
'800 PRO-RMK 155',
'800 PRO-RMK LE',
'800 PRO-RMK 163 Terrain Dominator',
'800 PRO-RMK 155 Terrain Dominator',
'800 PRO-RMK 155 3in.',
'800 PRO-RMK 163 3in.',
'800 PRO-RMK 174 LE',
'800 PRO-RMK 155 LE',
'800 PRO-RMK 163 LE',
'800 PRO-RMK 174',
'800 SKS',
'800 SKS 155',
'800 SKS 146',
'850 SKS 155',
'850 SKS 146'

]

#Range of Years
years = list(range(2016, 2022))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                              Model Vendor Code  \
# 0    POLARIS                    600 PRO-RMK 155        NACH
# 1    POLARIS                    800 PRO-RMK 163        NACH
# 2    POLARIS                    800 PRO-RMK 155        NACH
# 3    POLARIS                     800 PRO-RMK LE        NACH
# 4    POLARIS  800 PRO-RMK 163 Terrain Dominator        NACH
# ..       ...                                ...         ...
# 97   POLARIS                            800 SKS        NACH
# 98   POLARIS                        800 SKS 155        NACH
# 99   POLARIS                        800 SKS 146        NACH
# 100  POLARIS                        850 SKS 155        NACH
# 101  POLARIS                        850 SKS 146        NACH
#
#                        Vendor Name Position        MPN AD LIST NUMBER  Year
# 0    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50002        1121012  2016
# 1    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50002        1121012  2016
# 2    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50002        1121012  2016
# 3    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50002        1121012  2016
# 4    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50002        1121012  2016
# ..                             ...      ...        ...            ...   ...
# 97   NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50002        1121012  2021
# 98   NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50002        1121012  2021
# 99   NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50002        1121012  2021
# 100  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50002        1121012  2021
# 101  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50002        1121012  2021
#
# [102 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\19.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['SKI-DOO'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['LEFT SKI'],
    
    'MPN': ['LS8-80000LH'],
    
    'AD LIST NUMBER': ['1121013'],
    
    
}


#list all models
list_models = [

'Freeride E-TEC 850 137',
'Freeride E-TEC 850 146',
'Freeride S-38 E-TEC 850 154',
'Freeride E-TEC 850 154',
'Freeride E-TEC 850 Turbo 154',
'Freeride E-TEC 850 Turbo 165',
'Freeride E-TEC 850 Turbo 146',
'Summit X E-TEC 800R 174',
'Summit X E-TEC 850 154',
'Summit X E-TEC 850 165',
'Summit SP E-TEC 850 154',
'Summit SP E-TEC 850 165',
'Summit X E-TEC 850 175',
'Summit SP E-TEC 850 146',
'Summit SP E-TEC 850 175',
'Summit X with Expert Package E-TEC 850 154',
'Summit X with Expert Package E-TEC 850 165',
'Summit X E-TEC 850 Turbo 154',
'Summit X E-TEC 850 Turbo 165',
'Summit X with Expert Package E-TEC 850 175',
'Summit X with Expert Package E-TEC 850 Turbo 154',
'Summit X with Expert Package E-TEC 850 Turbo 165',
'Summit X with Expert Package E-TEC 850 Turbo 175',
'Summit X w/ Expert Package E-TEC 850 Turbo 154 2.5',
'Summit Edge E-TEC 850 175',
'Summit Edge E-TEC 850 154',
'Summit X with Expert Package E-TEC 850 154 2.5',
'Summit Edge E-TEC 850 165',
'Summit X E-TEC 850 Turbo R 154',
'Summit X E-TEC 850 Turbo R 165',
'Summit X with Expert Package E-TEC 850 Turbo R 154',
'Summit X with Expert Package E-TEC 850 Turbo R 165',
'Summit X with Expert Package E-TEC 850 Turbo R 175'

]

#Range of Years
years = list(range(2017, 2024))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                                              Model Vendor Code  \
# 0    SKI-DOO                             Freeride E-TEC 850 137        NACH
# 1    SKI-DOO                             Freeride E-TEC 850 146        NACH
# 2    SKI-DOO                        Freeride S-38 E-TEC 850 154        NACH
# 3    SKI-DOO                             Freeride E-TEC 850 154        NACH
# 4    SKI-DOO                       Freeride E-TEC 850 Turbo 154        NACH
# ..       ...                                                ...         ...
# 226  SKI-DOO                     Summit X E-TEC 850 Turbo R 154        NACH
# 227  SKI-DOO                     Summit X E-TEC 850 Turbo R 165        NACH
# 228  SKI-DOO  Summit X with Expert Package E-TEC 850 Turbo R...        NACH
# 229  SKI-DOO  Summit X with Expert Package E-TEC 850 Turbo R...        NACH
# 230  SKI-DOO  Summit X with Expert Package E-TEC 850 Turbo R...        NACH
#
#                        Vendor Name  Position          MPN AD LIST NUMBER  Year
# 0    NACHMAN INTERNATIONAL CO. LTD  LEFT SKI  LS8-80000LH        1121013  2017
# 1    NACHMAN INTERNATIONAL CO. LTD  LEFT SKI  LS8-80000LH        1121013  2017
# 2    NACHMAN INTERNATIONAL CO. LTD  LEFT SKI  LS8-80000LH        1121013  2017
# 3    NACHMAN INTERNATIONAL CO. LTD  LEFT SKI  LS8-80000LH        1121013  2017
# 4    NACHMAN INTERNATIONAL CO. LTD  LEFT SKI  LS8-80000LH        1121013  2017
# ..                             ...       ...          ...            ...   ...
# 226  NACHMAN INTERNATIONAL CO. LTD  LEFT SKI  LS8-80000LH        1121013  2023
# 227  NACHMAN INTERNATIONAL CO. LTD  LEFT SKI  LS8-80000LH        1121013  2023
# 228  NACHMAN INTERNATIONAL CO. LTD  LEFT SKI  LS8-80000LH        1121013  2023
# 229  NACHMAN INTERNATIONAL CO. LTD  LEFT SKI  LS8-80000LH        1121013  2023
# 230  NACHMAN INTERNATIONAL CO. LTD  LEFT SKI  LS8-80000LH        1121013  2023
#
# [231 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\20.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['SKI-DOO'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['RIGHT SKI'],
    
    'MPN': ['LS8-80000RH'],
    
    'AD LIST NUMBER': ['1121014'],
    
    
}


#list all models
list_models = [

'Freeride E-TEC 850 137',
'Freeride E-TEC 850 146',
'Freeride S-38 E-TEC 850 154',
'Freeride E-TEC 850 154',
'Freeride E-TEC 850 Turbo 154',
'Freeride E-TEC 850 Turbo 165',
'Freeride E-TEC 850 Turbo 146',
'Summit X E-TEC 800R 174',
'Summit X E-TEC 850 154',
'Summit X E-TEC 850 165',
'Summit SP E-TEC 850 154',
'Summit SP E-TEC 850 165',
'Summit X E-TEC 850 175',
'Summit SP E-TEC 850 146',
'Summit SP E-TEC 850 175',
'Summit X with Expert Package E-TEC 850 154',
'Summit X with Expert Package E-TEC 850 165',
'Summit X E-TEC 850 Turbo 154',
'Summit X E-TEC 850 Turbo 165',
'Summit X with Expert Package E-TEC 850 175',
'Summit X with Expert Package E-TEC 850 Turbo 154',
'Summit X with Expert Package E-TEC 850 Turbo 165',
'Summit X with Expert Package E-TEC 850 Turbo 175',
'Summit X w/ Expert Package E-TEC 850 Turbo 154 2.5',
'Summit Edge E-TEC 850 175',
'Summit Edge E-TEC 850 154',
'Summit X with Expert Package E-TEC 850 154 2.5',
'Summit Edge E-TEC 850 165',
'Summit X E-TEC 850 Turbo R 154',
'Summit X E-TEC 850 Turbo R 165',
'Summit X with Expert Package E-TEC 850 Turbo R 154',
'Summit X with Expert Package E-TEC 850 Turbo R 165',
'Summit X with Expert Package E-TEC 850 Turbo R 175'

]

#Range of Years
years = list(range(2017, 2024))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                                              Model Vendor Code  \
# 0    SKI-DOO                             Freeride E-TEC 850 137        NACH
# 1    SKI-DOO                             Freeride E-TEC 850 146        NACH
# 2    SKI-DOO                        Freeride S-38 E-TEC 850 154        NACH
# 3    SKI-DOO                             Freeride E-TEC 850 154        NACH
# 4    SKI-DOO                       Freeride E-TEC 850 Turbo 154        NACH
# ..       ...                                                ...         ...
# 226  SKI-DOO                     Summit X E-TEC 850 Turbo R 154        NACH
# 227  SKI-DOO                     Summit X E-TEC 850 Turbo R 165        NACH
# 228  SKI-DOO  Summit X with Expert Package E-TEC 850 Turbo R...        NACH
# 229  SKI-DOO  Summit X with Expert Package E-TEC 850 Turbo R...        NACH
# 230  SKI-DOO  Summit X with Expert Package E-TEC 850 Turbo R...        NACH
#
#                        Vendor Name   Position          MPN AD LIST NUMBER  \
# 0    NACHMAN INTERNATIONAL CO. LTD  RIGHT SKI  LS8-80000RH        1121014
# 1    NACHMAN INTERNATIONAL CO. LTD  RIGHT SKI  LS8-80000RH        1121014
# 2    NACHMAN INTERNATIONAL CO. LTD  RIGHT SKI  LS8-80000RH        1121014
# 3    NACHMAN INTERNATIONAL CO. LTD  RIGHT SKI  LS8-80000RH        1121014
# 4    NACHMAN INTERNATIONAL CO. LTD  RIGHT SKI  LS8-80000RH        1121014
# ..                             ...        ...          ...            ...
# 226  NACHMAN INTERNATIONAL CO. LTD  RIGHT SKI  LS8-80000RH        1121014
# 227  NACHMAN INTERNATIONAL CO. LTD  RIGHT SKI  LS8-80000RH        1121014
# 228  NACHMAN INTERNATIONAL CO. LTD  RIGHT SKI  LS8-80000RH        1121014
# 229  NACHMAN INTERNATIONAL CO. LTD  RIGHT SKI  LS8-80000RH        1121014
# 230  NACHMAN INTERNATIONAL CO. LTD  RIGHT SKI  LS8-80000RH        1121014
#
#      Year
# 0    2017
# 1    2017
# 2    2017
# 3    2017
# 4    2017
# ..    ...
# 226  2023
# 227  2023
# 228  2023
# 229  2023
# 230  2023
#
# [231 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\21.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['SKI-DOO'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['LEFT SKI'],
    
    'MPN': ['LS8-80001LH'],
    
    'AD LIST NUMBER': ['1121015'],
    
    
}


#list all models
list_models = [

'MX Z X-RS E-TEC 800R',
'MX Z X E-TEC 850',
'MX Z TNT E-TEC 850',
'MX Z X 4-TEC 1200',
'MX Z X E-TEC 600 HO',
'MX Z Blizzard 4-TEC 1200',
'MX Z Blizzard ACE 900',
'MX Z Blizzard E-TEC 800R',
'MX Z Blizzard E-TEC 600 HO',
'MX Z TNT 4-TEC 1200',
'MX Z TNT ACE 900',
'MX Z TNT E-TEC 600 HO',
'MX Z Sport 600 ACE',
'MX Z Sport 600 Carb',
'MX Z X-RS Iron Dog E-TEC 600 HO',
'MX Z X-RS E-TEC 850',
'MX Z Blizzard E-TEC 850',
'MX Z Blizzard E-TEC 600R',
'MX Z TNT E-TEC 600R',
'MX Z X E-TEC 600R',
'MX Z X-RS E-TEC 600R',
'MX Z Sport 600 EFI',
'MX Z Neo 600 EFI-40',
'MX Z Neo+ 600 EFI-55',
'Renegade X-RS E-TEC 800R',
'Renegade X E-TEC 850',
'Renegade X E-TEC 600 HO',
'Renegade X 4-TEC 1200',
'Renegade Backcountry X E-TEC 800R',
'Renegade Enduro 4-TEC 1200',
'Renegade Enduro ACE 900',
'Renegade Enduro E-TEC 800R',
'Renegade Enduro E-TEC 600 HO',
'Renegade Adrenaline E-TEC 850',
'Renegade Adrenaline 4-TEC 1200',
'Renegade Adrenaline ACE 900',
'Renegade Adrenaline E-TEC 600 HO',
'Renegade Backcountry E-TEC 600 HO',
'Renegade Backcountry E-TEC 800R',
'Renegade Sport 600 ACE',
'Renegade Sport 600 Carb',
'Renegade X-RS E-TEC 850',
'Renegade Backcountry X E-TEC 850',
'Renegade Backcountry E-TEC 850',
'Renegade Adrenaline E-TEC 600R',
'Renegade Adrenaline ACE 900 Turbo',
'Renegade Enduro E-TEC 600R',
'Renegade Enduro E-TEC 850',
'Renegade Enduro ACE 900 Turbo',
'Renegade X E-TEC 600R',
'Renegade X ACE 900 Turbo',
'Renegade X-RS ACE 900 Turbo',
'Renegade Sport 600 EFI',
'Renegade Adrenaline ACE 900 Turbo R',
'Renegade X-RS ACE 900 Turbo R',
'Renegade Enduro ACE 900 Turbo R',
'Renegade X-RS with Comp Package E-TEC 600R',
'Renegade X ACE 900 Turbo R'

]

#Range of Years
years = list(range(2015, 2020))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                                       Model Vendor Code  \
# 0    SKI-DOO                        MX Z X-RS E-TEC 800R        NACH
# 1    SKI-DOO                            MX Z X E-TEC 850        NACH
# 2    SKI-DOO                          MX Z TNT E-TEC 850        NACH
# 3    SKI-DOO                           MX Z X 4-TEC 1200        NACH
# 4    SKI-DOO                         MX Z X E-TEC 600 HO        NACH
# ..       ...                                         ...         ...
# 285  SKI-DOO         Renegade Adrenaline ACE 900 Turbo R        NACH
# 286  SKI-DOO               Renegade X-RS ACE 900 Turbo R        NACH
# 287  SKI-DOO             Renegade Enduro ACE 900 Turbo R        NACH
# 288  SKI-DOO  Renegade X-RS with Comp Package E-TEC 600R        NACH
# 289  SKI-DOO                  Renegade X ACE 900 Turbo R        NACH
#
#                        Vendor Name  Position          MPN AD LIST NUMBER  Year
# 0    NACHMAN INTERNATIONAL CO. LTD  LEFT SKI  LS8-80001LH        1121015  2015
# 1    NACHMAN INTERNATIONAL CO. LTD  LEFT SKI  LS8-80001LH        1121015  2015
# 2    NACHMAN INTERNATIONAL CO. LTD  LEFT SKI  LS8-80001LH        1121015  2015
# 3    NACHMAN INTERNATIONAL CO. LTD  LEFT SKI  LS8-80001LH        1121015  2015
# 4    NACHMAN INTERNATIONAL CO. LTD  LEFT SKI  LS8-80001LH        1121015  2015
# ..                             ...       ...          ...            ...   ...
# 285  NACHMAN INTERNATIONAL CO. LTD  LEFT SKI  LS8-80001LH        1121015  2019
# 286  NACHMAN INTERNATIONAL CO. LTD  LEFT SKI  LS8-80001LH        1121015  2019
# 287  NACHMAN INTERNATIONAL CO. LTD  LEFT SKI  LS8-80001LH        1121015  2019
# 288  NACHMAN INTERNATIONAL CO. LTD  LEFT SKI  LS8-80001LH        1121015  2019
# 289  NACHMAN INTERNATIONAL CO. LTD  LEFT SKI  LS8-80001LH        1121015  2019
#
# [290 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\22.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['SKI-DOO'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['RIGHT SKI'],
    
    'MPN': ['LS8-80001RH'],
    
    'AD LIST NUMBER': ['1121016'],
    
    
}


#list all models
list_models = [

'MX Z X-RS E-TEC 800R',
'MX Z X E-TEC 850',
'MX Z TNT E-TEC 850',
'MX Z X 4-TEC 1200',
'MX Z X E-TEC 600 HO',
'MX Z Blizzard 4-TEC 1200',
'MX Z Blizzard ACE 900',
'MX Z Blizzard E-TEC 800R',
'MX Z Blizzard E-TEC 600 HO',
'MX Z TNT 4-TEC 1200',
'MX Z TNT ACE 900',
'MX Z TNT E-TEC 600 HO',
'MX Z Sport 600 ACE',
'MX Z Sport 600 Carb',
'MX Z X-RS Iron Dog E-TEC 600 HO',
'MX Z X-RS E-TEC 850',
'MX Z Blizzard E-TEC 850',
'MX Z Blizzard E-TEC 600R',
'MX Z TNT E-TEC 600R',
'MX Z X E-TEC 600R',
'MX Z X-RS E-TEC 600R',
'MX Z Sport 600 EFI',
'MX Z Neo 600 EFI-40',
'MX Z Neo+ 600 EFI-55',
'Renegade X-RS E-TEC 800R',
'Renegade X E-TEC 850',
'Renegade X E-TEC 600 HO',
'Renegade X 4-TEC 1200',
'Renegade Backcountry X E-TEC 800R',
'Renegade Enduro 4-TEC 1200',
'Renegade Enduro ACE 900',
'Renegade Enduro E-TEC 800R',
'Renegade Enduro E-TEC 600 HO',
'Renegade Adrenaline E-TEC 850',
'Renegade Adrenaline 4-TEC 1200',
'Renegade Adrenaline ACE 900',
'Renegade Adrenaline E-TEC 600 HO',
'Renegade Backcountry E-TEC 600 HO',
'Renegade Backcountry E-TEC 800R',
'Renegade Sport 600 ACE',
'Renegade Sport 600 Carb',
'Renegade X-RS E-TEC 850',
'Renegade Backcountry X E-TEC 850',
'Renegade Backcountry E-TEC 850',
'Renegade Adrenaline E-TEC 600R',
'Renegade Adrenaline ACE 900 Turbo',
'Renegade Enduro E-TEC 600R',
'Renegade Enduro E-TEC 850',
'Renegade Enduro ACE 900 Turbo',
'Renegade X E-TEC 600R',
'Renegade X ACE 900 Turbo',
'Renegade X-RS ACE 900 Turbo',
'Renegade Sport 600 EFI',
'Renegade Adrenaline ACE 900 Turbo R',
'Renegade X-RS ACE 900 Turbo R',
'Renegade Enduro ACE 900 Turbo R',
'Renegade X-RS with Comp Package E-TEC 600R',
'Renegade X ACE 900 Turbo R'

]

#Range of Years
years = list(range(2015, 2020))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                                       Model Vendor Code  \
# 0    SKI-DOO                        MX Z X-RS E-TEC 800R        NACH
# 1    SKI-DOO                            MX Z X E-TEC 850        NACH
# 2    SKI-DOO                          MX Z TNT E-TEC 850        NACH
# 3    SKI-DOO                           MX Z X 4-TEC 1200        NACH
# 4    SKI-DOO                         MX Z X E-TEC 600 HO        NACH
# ..       ...                                         ...         ...
# 285  SKI-DOO         Renegade Adrenaline ACE 900 Turbo R        NACH
# 286  SKI-DOO               Renegade X-RS ACE 900 Turbo R        NACH
# 287  SKI-DOO             Renegade Enduro ACE 900 Turbo R        NACH
# 288  SKI-DOO  Renegade X-RS with Comp Package E-TEC 600R        NACH
# 289  SKI-DOO                  Renegade X ACE 900 Turbo R        NACH
#
#                        Vendor Name   Position          MPN AD LIST NUMBER  \
# 0    NACHMAN INTERNATIONAL CO. LTD  RIGHT SKI  LS8-80001RH        1121016
# 1    NACHMAN INTERNATIONAL CO. LTD  RIGHT SKI  LS8-80001RH        1121016
# 2    NACHMAN INTERNATIONAL CO. LTD  RIGHT SKI  LS8-80001RH        1121016
# 3    NACHMAN INTERNATIONAL CO. LTD  RIGHT SKI  LS8-80001RH        1121016
# 4    NACHMAN INTERNATIONAL CO. LTD  RIGHT SKI  LS8-80001RH        1121016
# ..                             ...        ...          ...            ...
# 285  NACHMAN INTERNATIONAL CO. LTD  RIGHT SKI  LS8-80001RH        1121016
# 286  NACHMAN INTERNATIONAL CO. LTD  RIGHT SKI  LS8-80001RH        1121016
# 287  NACHMAN INTERNATIONAL CO. LTD  RIGHT SKI  LS8-80001RH        1121016
# 288  NACHMAN INTERNATIONAL CO. LTD  RIGHT SKI  LS8-80001RH        1121016
# 289  NACHMAN INTERNATIONAL CO. LTD  RIGHT SKI  LS8-80001RH        1121016
#
#      Year
# 0    2015
# 1    2015
# 2    2015
# 3    2015
# 4    2015
# ..    ...
# 285  2019
# 286  2019
# 287  2019
# 288  2019
# 289  2019
#
# [290 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\23.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['SKI-DOO'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['REAR SUSPENSION'],
    
    'MPN': ['LS4-11000K'],
    
    'AD LIST NUMBER': ['1121017'],
    
    
}


#list all models
list_models = [


'ZR 7000 LXR 129',
'ZR 7000 LXR 137',
'ZR 7000 Sno Pro 129',
'ZR 7000 Sno Pro 137',
'ZR 7000 Limited 129',
'ZR 7000 Limited 137',
'ZR 7000 El Tigre',
'ZR 7000 RR',
'ZR 7000 129',
'ZR 7000 137',
'ZR 7000 Limited 137 iACT',
'ZR 9000 LXR',
'ZR 9000 Sno Pro 129',
'ZR 9000 Sno Pro 137',
'ZR 9000 Limited 129',
'ZR 9000 Limited 137',
'ZR 9000 El Tigre',
'ZR 9000 RR',
'ZR 9000 RR 129',
'ZR 9000 RR 137',
'ZR 9000 Thundercat',
'ZR 9000 Thundercat iACT',
'ZR 9000 Limited',
'ZR 9000 Limited iACT',
'ZR 9000 Thundercat ATAC',
'ZR 9000 Thundercat EPS',
'ZR 9000 Thundercat EPS ATAC'

]

#Range of Years
years = list(range(2016, 2024))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                        Model Vendor Code  \
# 0    SKI-DOO              ZR 7000 LXR 129        NACH
# 1    SKI-DOO              ZR 7000 LXR 137        NACH
# 2    SKI-DOO          ZR 7000 Sno Pro 129        NACH
# 3    SKI-DOO          ZR 7000 Sno Pro 137        NACH
# 4    SKI-DOO          ZR 7000 Limited 129        NACH
# ..       ...                          ...         ...
# 211  SKI-DOO              ZR 9000 Limited        NACH
# 212  SKI-DOO         ZR 9000 Limited iACT        NACH
# 213  SKI-DOO      ZR 9000 Thundercat ATAC        NACH
# 214  SKI-DOO       ZR 9000 Thundercat EPS        NACH
# 215  SKI-DOO  ZR 9000 Thundercat EPS ATAC        NACH
#
#                        Vendor Name         Position         MPN  \
# 0    NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-11000K
# 1    NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-11000K
# 2    NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-11000K
# 3    NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-11000K
# 4    NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-11000K
# ..                             ...              ...         ...
# 211  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-11000K
# 212  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-11000K
# 213  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-11000K
# 214  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-11000K
# 215  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-11000K
#
#     AD LIST NUMBER  Year
# 0          1121017  2016
# 1          1121017  2016
# 2          1121017  2016
# 3          1121017  2016
# 4          1121017  2016
# ..             ...   ...
# 211        1121017  2023
# 212        1121017  2023
# 213        1121017  2023
# 214        1121017  2023
# 215        1121017  2023
#
# [216 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\24.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['SKI-DOO'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['REAR SUSPENSION'],
    
    'MPN': ['LS4-50000K'],
    
    'AD LIST NUMBER': ['1121018'],
    
    
}


#list all models
list_models = [



'600 SwitchBack SP 144',
'600 SwitchBack PRO-S',
'600 SwitchBack Assault 144',
'600 SwitchBack Adventure',
'600 SwitchBack XCR',
'800 SKS 155',
'800 SKS 146',
'800 SwitchBack PRO-X',
'800 SwitchBack PRO-S LE',
'800 SwitchBack PRO-S',
'800 SwitchBack Assault 144',
'800 SwitchBack Adventure',
'800 SwitchBack XCR',
'850 SwitchBack Assault 144',
'850 SwitchBack PRO-S',
'850 SwitchBack XCR',
'850 SwitchBack Assault 146',
'850 SwitchBack XC 146'

]

#Range of Years
years = list(range(2017, 2022))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#        Make                       Model Vendor Code  \
# 0   SKI-DOO       600 SwitchBack SP 144        NACH
# 1   SKI-DOO        600 SwitchBack PRO-S        NACH
# 2   SKI-DOO  600 SwitchBack Assault 144        NACH
# 3   SKI-DOO    600 SwitchBack Adventure        NACH
# 4   SKI-DOO          600 SwitchBack XCR        NACH
# ..      ...                         ...         ...
# 85  SKI-DOO  850 SwitchBack Assault 144        NACH
# 86  SKI-DOO        850 SwitchBack PRO-S        NACH
# 87  SKI-DOO          850 SwitchBack XCR        NACH
# 88  SKI-DOO  850 SwitchBack Assault 146        NACH
# 89  SKI-DOO       850 SwitchBack XC 146        NACH
#
#                       Vendor Name         Position         MPN AD LIST NUMBER  \
# 0   NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-50000K        1121018
# 1   NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-50000K        1121018
# 2   NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-50000K        1121018
# 3   NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-50000K        1121018
# 4   NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-50000K        1121018
# ..                            ...              ...         ...            ...
# 85  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-50000K        1121018
# 86  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-50000K        1121018
# 87  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-50000K        1121018
# 88  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-50000K        1121018
# 89  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-50000K        1121018
#
#     Year
# 0   2017
# 1   2017
# 2   2017
# 3   2017
# 4   2017
# ..   ...
# 85  2021
# 86  2021
# 87  2021
# 88  2021
# 89  2021
#
# [90 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\25.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['SKI-DOO'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['REAR SUSPENSION'],
    
    'MPN': ['LS4-50001K'],
    
    'AD LIST NUMBER': ['1121019'],
    
    
}


#list all models
list_models = [



'600 SwitchBack SP 144',
'600 SwitchBack PRO-S',
'600 SwitchBack Assault 144',
'600 SwitchBack Adventure',
'600 SwitchBack XCR',
'800 SKS 155',
'800 SKS 146',
'800 SwitchBack PRO-X',
'800 SwitchBack PRO-S LE',
'800 SwitchBack PRO-S',
'800 SwitchBack Assault 144',
'800 SwitchBack Adventure',
'800 SwitchBack XCR',
'850 SwitchBack Assault 144',
'850 SwitchBack PRO-S',
'850 SwitchBack XCR',
'850 SwitchBack Assault 146',
'850 SwitchBack XC 146'

]

#Range of Years
years = list(range(2012, 2018))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                       Model Vendor Code  \
# 0    SKI-DOO       600 SwitchBack SP 144        NACH
# 1    SKI-DOO        600 SwitchBack PRO-S        NACH
# 2    SKI-DOO  600 SwitchBack Assault 144        NACH
# 3    SKI-DOO    600 SwitchBack Adventure        NACH
# 4    SKI-DOO          600 SwitchBack XCR        NACH
# ..       ...                         ...         ...
# 103  SKI-DOO  850 SwitchBack Assault 144        NACH
# 104  SKI-DOO        850 SwitchBack PRO-S        NACH
# 105  SKI-DOO          850 SwitchBack XCR        NACH
# 106  SKI-DOO  850 SwitchBack Assault 146        NACH
# 107  SKI-DOO       850 SwitchBack XC 146        NACH
#
#                        Vendor Name         Position         MPN  \
# 0    NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-50001K
# 1    NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-50001K
# 2    NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-50001K
# 3    NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-50001K
# 4    NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-50001K
# ..                             ...              ...         ...
# 103  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-50001K
# 104  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-50001K
# 105  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-50001K
# 106  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-50001K
# 107  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-50001K
#
#     AD LIST NUMBER  Year
# 0          1121019  2012
# 1          1121019  2012
# 2          1121019  2012
# 3          1121019  2012
# 4          1121019  2012
# ..             ...   ...
# 103        1121019  2017
# 104        1121019  2017
# 105        1121019  2017
# 106        1121019  2017
# 107        1121019  2017
#
# [108 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\26.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['SKI-DOO'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['REAR SUSPENSION'],
    
    'MPN': ['LS4-80000K'],
    
    'AD LIST NUMBER': ['1121020'],
    
    
}


#list all models
list_models = [

'Freeride E-TEC 800R 137',
'Freeride E-TEC 800R 146',
'Freeride E-TEC 800R 154',
'Freeride E-TEC 850 137',
'Freeride E-TEC 850 146',
'Freeride E-TEC 850 154',
'Freeride E-TEC 850 165',
'Freeride E-TEC 850 Turbo 154',
'Freeride E-TEC 850 Turbo 165',
'Freeride E-TEC 850 Turbo 146',
'Renegade 600 Backcountry',
'Renegade 600 Adrenaline',
'Renegade 600 X',
'Renegade 800 Backcountry',
'Renegade 800 Adrenaline',
'Renegade 800 Backcountry X',
'Renegade 800 X',
'Summit 600',
'Summit 600 R Sport',
'Summit 600 Sport',
'Summit 600 Adrenaline',
'Summit 600 X',
'Summit 600 X 154',
'Summit 600 Everest 146',
'Summit 600 Everest',
'Summit 800 R Everest',
'Summit 800 X 144',
'Summit 800 XRS 151',
'Summit 800 X',
'Summit 800 Highmark',
'Summit 800 Highmark X',
'Summit 800 Foothill',
'Summit 800',
'Summit 800 Sport',
'Summit 800 R Sport',
'Summit 800 R X',
'Summit 800 R Highmark X',
'Summit 800 R Highmark',
'Summit 800 Adrenaline 144',
'Summit 800 Highmark Xtreme',
'Summit 800 Adrenaline 151',
'Summit 800 X 163',
'Summit 800 X 154',
'Summit 800 Hill Climb',
'Summit 800 Everest 163',
'Summit 800 Everest 154',
'Summit 800 Everest 146',
'Summit 800 X 146',
'Summit 800 XRS 159',
'Summit 800 X 151',
'Summit 800 X 159',
'Summit 800 R 50th Anniversary',
'Summit X E-TEC 850 154',
'Summit X E-TEC 850 165',
'Summit SP E-TEC 850 154',
'Summit SP E-TEC 850 165',
'Summit X E-TEC 850 175',
'Summit SP E-TEC 850 146',
'Summit SP E-TEC 850 175',
'Summit X with Expert Package E-TEC 850 154',
'Summit X with Expert Package E-TEC 850 165',
'Summit X E-TEC 850 Turbo 154',
'Summit X E-TEC 850 Turbo 165',
'Summit X with Expert Package E-TEC 850 175',
'Summit X with Expert Package E-TEC 850 Turbo 154',
'Summit X with Expert Package E-TEC 850 Turbo 165',
'Summit X with Expert Package E-TEC 850 Turbo 175',
'Summit X w/ Expert Package E-TEC 850 Turbo 154 2.5',
'Summit Edge E-TEC 850 175',
'Summit Edge E-TEC 850 154',
'Summit X with Expert Package E-TEC 850 154 2.5',
'Summit Edge E-TEC 850 165',
'Summit X E-TEC 850 Turbo R 154',
'Summit X E-TEC 850 Turbo R 165',
'Summit X with Expert Package E-TEC 850 Turbo R 154',
'Summit X with Expert Package E-TEC 850 Turbo R 165',
'Summit X with Expert Package E-TEC 850 Turbo R 175'


]

#Range of Years
years = list(range(2015, 2024))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                                              Model Vendor Code  \
# 0    SKI-DOO                            Freeride E-TEC 800R 137        NACH
# 1    SKI-DOO                            Freeride E-TEC 800R 146        NACH
# 2    SKI-DOO                            Freeride E-TEC 800R 154        NACH
# 3    SKI-DOO                             Freeride E-TEC 850 137        NACH
# 4    SKI-DOO                             Freeride E-TEC 850 146        NACH
# ..       ...                                                ...         ...
# 688  SKI-DOO                     Summit X E-TEC 850 Turbo R 154        NACH
# 689  SKI-DOO                     Summit X E-TEC 850 Turbo R 165        NACH
# 690  SKI-DOO  Summit X with Expert Package E-TEC 850 Turbo R...        NACH
# 691  SKI-DOO  Summit X with Expert Package E-TEC 850 Turbo R...        NACH
# 692  SKI-DOO  Summit X with Expert Package E-TEC 850 Turbo R...        NACH
#
#                        Vendor Name         Position         MPN  \
# 0    NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-80000K
# 1    NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-80000K
# 2    NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-80000K
# 3    NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-80000K
# 4    NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-80000K
# ..                             ...              ...         ...
# 688  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-80000K
# 689  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-80000K
# 690  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-80000K
# 691  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-80000K
# 692  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-80000K
#
#     AD LIST NUMBER  Year
# 0          1121020  2015
# 1          1121020  2015
# 2          1121020  2015
# 3          1121020  2015
# 4          1121020  2015
# ..             ...   ...
# 688        1121020  2023
# 689        1121020  2023
# 690        1121020  2023
# 691        1121020  2023
# 692        1121020  2023
#
# [693 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\27.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['SKI-DOO'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['REAR SUSPENSION'],
    
    'MPN': ['LS4-80001K'],
    
    'AD LIST NUMBER': ['1121021'],
    
    
}


#list all models
list_models = [

'MX Z X-RS E-TEC 600 HO',
'MX Z X-RS E-TEC 800R',
'MX Z X E-TEC 600 HO',
'MX Z X E-TEC 800R',
'MX Z X 4-TEC 1200',
'MX Z TNT E-TEC 600 HO',
'MX Z TNT E-TEC 800R',
'MX Z TNT ACE 900',
'MX Z TNT 4-TEC 1200',
'MX Z Sport 600 ACE',
'MX Z Sport 600 Carb',
'MX Z Blizzard E-TEC 600 HO',
'MX Z Blizzard E-TEC 800R',
'MX Z Blizzard ACE 900',
'MX Z Blizzard 4-TEC 1200',
'MX Z X E-TEC 850',
'MX Z TNT E-TEC 850',
'MX Z X-RS Iron Dog E-TEC 600 HO',
'MX Z X-RS E-TEC 850',
'MX Z Blizzard E-TEC 850',
'MX Z Blizzard E-TEC 600R',
'MX Z TNT E-TEC 600R',
'MX Z X E-TEC 600R',
'MX Z X-RS E-TEC 600R',
'MX Z Sport 600 EFI',
'MX Z Neo 600 EFI-40',
'MX Z Neo+ 600 EFI-55'



]

#Range of Years
years = list(range(2015, 2021))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                   Model Vendor Code  \
# 0    SKI-DOO  MX Z X-RS E-TEC 600 HO        NACH
# 1    SKI-DOO    MX Z X-RS E-TEC 800R        NACH
# 2    SKI-DOO     MX Z X E-TEC 600 HO        NACH
# 3    SKI-DOO       MX Z X E-TEC 800R        NACH
# 4    SKI-DOO       MX Z X 4-TEC 1200        NACH
# ..       ...                     ...         ...
# 157  SKI-DOO       MX Z X E-TEC 600R        NACH
# 158  SKI-DOO    MX Z X-RS E-TEC 600R        NACH
# 159  SKI-DOO      MX Z Sport 600 EFI        NACH
# 160  SKI-DOO     MX Z Neo 600 EFI-40        NACH
# 161  SKI-DOO    MX Z Neo+ 600 EFI-55        NACH
#
#                        Vendor Name         Position         MPN  \
# 0    NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-80001K
# 1    NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-80001K
# 2    NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-80001K
# 3    NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-80001K
# 4    NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-80001K
# ..                             ...              ...         ...
# 157  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-80001K
# 158  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-80001K
# 159  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-80001K
# 160  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-80001K
# 161  NACHMAN INTERNATIONAL CO. LTD  REAR SUSPENSION  LS4-80001K
#
#     AD LIST NUMBER  Year
# 0          1121021  2015
# 1          1121021  2015
# 2          1121021  2015
# 3          1121021  2015
# 4          1121021  2015
# ..             ...   ...
# 157        1121021  2020
# 158        1121021  2020
# 159        1121021  2020
# 160        1121021  2020
# 161        1121021  2020
#
# [162 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\28.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['ARCTIC CAT'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['SKI'],
    
    'MPN': ['LS8-11000K'],
    
    'AD LIST NUMBER': ['1121022'],
    
    
}


#list all models
list_models = [

'ProCross F 800 Tucker Hibbert Race Replica',
'ProCross F 800 Sno Pro RR',
'ProCross F 800 Sno Pro Limited',
'ProCross F 800 Sno Pro',
'ProCross F 800 LXR',
'ProCross XF 1100 Turbo Sno Pro 50th',
'ProCross XF 1100 Turbo Sno Pro Limited',
'ProCross XF 1100 Turbo Sno Pro',
'ProCross XF 1100 Turbo LXR',
'ProCross XF 1100 Sno Pro 50th',
'ProCross XF 1100 Sno Pro Limited',
'ProCross XF 1100 Sno Pro',
'ProCross XF 1100 LXR',
'ProCross XF 1100 Turbo Crosstour',
'ProCross XF 1100 Crosstour',
'XF 8000 Sno Pro',
'XF 8000 LXR',
'XF 8000 Limited',
'XF 8000 High Country Limited',
'XF 8000 High Country',
'XF 8000 Crosstrek',
'XF 8000 Crosstour',
'XF 8000 Cross Country Sno Pro',
'XF 7000 LXR',
'XF 7000 Sno Pro',
'XF 7000 Limited',
'XF 7000 Crosstour',
'XF 7000 Cross Country Sno Pro',
'XF 8000 Cross Country Limited',
'XF 8000 Cross Country',
'XF 9000 High Country Limited',
'XF 9000 High Country Sno Pro',
'XF 9000 Crosstour',
'XF 9000 Cross Country Sno Pro',
'XF 9000 LXR',
'XF 9000 Sno Pro',
'XF 9000 Limited',
'XF 6000 LXR',
'XF 6000 Sno Pro',
'XF 6000 Limited',
'XF 6000 Crosstour',
'XF 6000 Cross Country',
'XF 6000 High Country',
'XF 7000 Cross Country',
'XF 7000 High Country',
'ProCross XF 800 Crosstour',
'XF 9000 Cross Country',
'XF 9000 High Country',
'XF 9000 Cross Country Limited',
'XF 6000 Crosstrek',
'XF 7000 Crosstrek',
'XF 9000 Crosstrek',
'ZR 5000 LXR',
'ZR 6000 El Tigre',
'ZR 6000 El Tigre ES',
'ZR 7000 LXR 129',
'ZR 7000 Sno Pro 129',
'ZR 7000 Limited 129',
'ZR 6000 RR',
'ZR 6000 LXR 129',
'ZR 6000 Sno Pro 129',
'ZR 6000 Limited 129',
'ZR 6000 Tucker Hibbert RR',
'ZR 7000 El Tigre',
'ZR 7000 RR',
'ZR 6000 LXR 137',
'ZR 6000 Sno Pro 137',
'ZR 6000 Limited 137',
'ZR 7000 LXR 137',
'ZR 7000 Sno Pro 137',
'ZR 7000 Limited 137'

]

#Range of Years
years = list(range(2012, 2022))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#            Make                                       Model Vendor Code  \
# 0    ARCTIC CAT  ProCross F 800 Tucker Hibbert Race Replica        NACH
# 1    ARCTIC CAT                   ProCross F 800 Sno Pro RR        NACH
# 2    ARCTIC CAT              ProCross F 800 Sno Pro Limited        NACH
# 3    ARCTIC CAT                      ProCross F 800 Sno Pro        NACH
# 4    ARCTIC CAT                          ProCross F 800 LXR        NACH
# ..          ...                                         ...         ...
# 705  ARCTIC CAT                         ZR 6000 Sno Pro 137        NACH
# 706  ARCTIC CAT                         ZR 6000 Limited 137        NACH
# 707  ARCTIC CAT                             ZR 7000 LXR 137        NACH
# 708  ARCTIC CAT                         ZR 7000 Sno Pro 137        NACH
# 709  ARCTIC CAT                         ZR 7000 Limited 137        NACH
#
#                        Vendor Name Position         MPN AD LIST NUMBER  Year
# 0    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-11000K        1121022  2012
# 1    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-11000K        1121022  2012
# 2    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-11000K        1121022  2012
# 3    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-11000K        1121022  2012
# 4    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-11000K        1121022  2012
# ..                             ...      ...         ...            ...   ...
# 705  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-11000K        1121022  2021
# 706  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-11000K        1121022  2021
# 707  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-11000K        1121022  2021
# 708  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-11000K        1121022  2021
# 709  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-11000K        1121022  2021
#
# [710 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\29.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['POLARIS'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['SKI'],
    
    'MPN': ['LS8-50000K'],
    
    'AD LIST NUMBER': ['1121023'],
    
    
}


#list all models
list_models = [



'600 INDY SP',
'600 INDY SP LE',
'600 INDY SP TD Series LE',
'600 INDY SP 129',
'600 INDY SP 137',
'600 SwitchBack Assault 144',
'600 SwitchBack SP 144',
'650 INDY Adventure 137',
'650 INDY Adventure X2 137',
'650 INDY VR1 137',
'650 INDY VR1 129',
'650 INDY XC Launch Edition 137',
'650 INDY XC Launch Edition 129',
'650 INDY XCR 136',
'650 INDY XCR 128',
'650 INDY XC 137',
'650 INDY XC 129',
'650 INDY SP 137',
'800 Rush PRO-X',
'800 SwitchBack Assault 144',
'800 SwitchBack Assault 144 TD Series LE',
'850 INDY XC 129',
'850 INDY XC 137',
'850 INDY XCR',
'850 INDY Adventure 137',
'850 INDY VR1 137',
'850 INDY VR1 129',
'850 INDY XC Launch Edition 137',
'850 INDY XC Launch Edition 129',
'850 INDY XCR 136',
'850 INDY XCR 128',
'Patriot Boost INDY VR1 129',
'Patriot Boost INDY VR1 137',
'Patriot Boost SwitchBack Assault 146'

]

#Range of Years
years = list(range(2017, 2025))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                                 Model Vendor Code  \
# 0    POLARIS                           600 INDY SP        NACH
# 1    POLARIS                        600 INDY SP LE        NACH
# 2    POLARIS              600 INDY SP TD Series LE        NACH
# 3    POLARIS                       600 INDY SP 129        NACH
# 4    POLARIS                       600 INDY SP 137        NACH
# ..       ...                                   ...         ...
# 267  POLARIS                      850 INDY XCR 136        NACH
# 268  POLARIS                      850 INDY XCR 128        NACH
# 269  POLARIS            Patriot Boost INDY VR1 129        NACH
# 270  POLARIS            Patriot Boost INDY VR1 137        NACH
# 271  POLARIS  Patriot Boost SwitchBack Assault 146        NACH
#
#                        Vendor Name Position         MPN AD LIST NUMBER  Year
# 0    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50000K        1121023  2017
# 1    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50000K        1121023  2017
# 2    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50000K        1121023  2017
# 3    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50000K        1121023  2017
# 4    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50000K        1121023  2017
# ..                             ...      ...         ...            ...   ...
# 267  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50000K        1121023  2024
# 268  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50000K        1121023  2024
# 269  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50000K        1121023  2024
# 270  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50000K        1121023  2024
# 271  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50000K        1121023  2024
#
# [272 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\30.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['POLARIS'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['SKI'],
    
    'MPN': ['LS8-50002K'],
    
    'AD LIST NUMBER': ['1121024'],
    
    
}


#list all models
list_models = [


'600 PRO-RMK 155',
'800 PRO-RMK 163',
'800 PRO-RMK 155',
'800 PRO-RMK LE',
'800 PRO-RMK 163 Terrain Dominator',
'800 PRO-RMK 155 Terrain Dominator',
'800 PRO-RMK 155 3in.',
'800 PRO-RMK 163 3in.',
'800 PRO-RMK 174 LE',
'800 PRO-RMK 155 LE',
'800 PRO-RMK 163 LE',
'800 PRO-RMK 174',
'800 SKS',
'800 SKS 155',
'800 SKS 146',
'850 SKS 155',
'850 SKS 146'

]

#Range of Years
years = list(range(2016, 2022))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                              Model Vendor Code  \
# 0    POLARIS                    600 PRO-RMK 155        NACH
# 1    POLARIS                    800 PRO-RMK 163        NACH
# 2    POLARIS                    800 PRO-RMK 155        NACH
# 3    POLARIS                     800 PRO-RMK LE        NACH
# 4    POLARIS  800 PRO-RMK 163 Terrain Dominator        NACH
# ..       ...                                ...         ...
# 97   POLARIS                            800 SKS        NACH
# 98   POLARIS                        800 SKS 155        NACH
# 99   POLARIS                        800 SKS 146        NACH
# 100  POLARIS                        850 SKS 155        NACH
# 101  POLARIS                        850 SKS 146        NACH
#
#                        Vendor Name Position         MPN AD LIST NUMBER  Year
# 0    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50002K        1121024  2016
# 1    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50002K        1121024  2016
# 2    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50002K        1121024  2016
# 3    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50002K        1121024  2016
# 4    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50002K        1121024  2016
# ..                             ...      ...         ...            ...   ...
# 97   NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50002K        1121024  2021
# 98   NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50002K        1121024  2021
# 99   NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50002K        1121024  2021
# 100  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50002K        1121024  2021
# 101  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-50002K        1121024  2021
#
# [102 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\31.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['SKI-DOO'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['SKI'],
    
    'MPN': ['LS8-80000K'],
    
    'AD LIST NUMBER': ['1121025'],
    
    
}


#list all models
list_models = [

'Freeride E-TEC 850 137',
'Freeride E-TEC 850 146',
'Freeride S-38 E-TEC 850 154',
'Freeride E-TEC 850 154',
'Freeride E-TEC 850 Turbo 154',
'Freeride E-TEC 850 Turbo 165',
'Freeride E-TEC 850 Turbo 146',
'Summit X E-TEC 800R 174',
'Summit X E-TEC 850 154',
'Summit X E-TEC 850 165',
'Summit SP E-TEC 850 154',
'Summit SP E-TEC 850 165',
'Summit X E-TEC 850 175',
'Summit SP E-TEC 850 146',
'Summit SP E-TEC 850 175',
'Summit X with Expert Package E-TEC 850 154',
'Summit X with Expert Package E-TEC 850 165',
'Summit X E-TEC 850 Turbo 154',
'Summit X E-TEC 850 Turbo 165',
'Summit X with Expert Package E-TEC 850 175',
'Summit X with Expert Package E-TEC 850 Turbo 154',
'Summit X with Expert Package E-TEC 850 Turbo 165',
'Summit X with Expert Package E-TEC 850 Turbo 175',
'Summit X w/ Expert Package E-TEC 850 Turbo 154 2.5',
'Summit Edge E-TEC 850 175',
'Summit Edge E-TEC 850 154',
'Summit X with Expert Package E-TEC 850 154 2.5',
'Summit Edge E-TEC 850 165',
'Summit X E-TEC 850 Turbo R 154',
'Summit X E-TEC 850 Turbo R 165',
'Summit X with Expert Package E-TEC 850 Turbo R 154',
'Summit X with Expert Package E-TEC 850 Turbo R 165',
'Summit X with Expert Package E-TEC 850 Turbo R 175'

]

#Range of Years
years = list(range(2017, 2024))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                                              Model Vendor Code  \
# 0    SKI-DOO                             Freeride E-TEC 850 137        NACH
# 1    SKI-DOO                             Freeride E-TEC 850 146        NACH
# 2    SKI-DOO                        Freeride S-38 E-TEC 850 154        NACH
# 3    SKI-DOO                             Freeride E-TEC 850 154        NACH
# 4    SKI-DOO                       Freeride E-TEC 850 Turbo 154        NACH
# ..       ...                                                ...         ...
# 226  SKI-DOO                     Summit X E-TEC 850 Turbo R 154        NACH
# 227  SKI-DOO                     Summit X E-TEC 850 Turbo R 165        NACH
# 228  SKI-DOO  Summit X with Expert Package E-TEC 850 Turbo R...        NACH
# 229  SKI-DOO  Summit X with Expert Package E-TEC 850 Turbo R...        NACH
# 230  SKI-DOO  Summit X with Expert Package E-TEC 850 Turbo R...        NACH
#
#                        Vendor Name Position         MPN AD LIST NUMBER  Year
# 0    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-80000K        1121025  2017
# 1    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-80000K        1121025  2017
# 2    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-80000K        1121025  2017
# 3    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-80000K        1121025  2017
# 4    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-80000K        1121025  2017
# ..                             ...      ...         ...            ...   ...
# 226  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-80000K        1121025  2023
# 227  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-80000K        1121025  2023
# 228  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-80000K        1121025  2023
# 229  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-80000K        1121025  2023
# 230  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-80000K        1121025  2023
#
# [231 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\32.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['SKI-DOO'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['SKI'],
    
    'MPN': ['LS8-80001K'],
    
    'AD LIST NUMBER': ['1121026'],
    
    
}


#list all models
list_models = [


'MX Z X-RS E-TEC 600 HO',
'MX Z X-RS E-TEC 800R',
'MX Z X E-TEC 600 HO',
'MX Z X E-TEC 800R',
'MX Z X 4-TEC 1200',
'MX Z TNT E-TEC 600 HO',
'MX Z TNT E-TEC 800R',
'MX Z TNT ACE 900',
'MX Z TNT 4-TEC 1200',
'MX Z Sport 600 ACE',
'MX Z Sport 600 Carb',
'MX Z Blizzard E-TEC 600 HO',
'MX Z Blizzard E-TEC 800R',
'MX Z Blizzard ACE 900',
'MX Z Blizzard 4-TEC 1200',
'MX Z X E-TEC 850',
'MX Z TNT E-TEC 850',
'MX Z X-RS Iron Dog E-TEC 600 HO',
'MX Z X-RS E-TEC 850',
'MX Z Blizzard E-TEC 850',
'MX Z Blizzard E-TEC 600R',
'MX Z TNT E-TEC 600R',
'MX Z X E-TEC 600R',
'MX Z X-RS E-TEC 600R',
'MX Z Sport 600 EFI',
'MX Z Neo 600 EFI-40',
'MX Z Neo+ 600 EFI-55'

]

#Range of Years
years = list(range(2015, 2020))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#         Make                   Model Vendor Code  \
# 0    SKI-DOO  MX Z X-RS E-TEC 600 HO        NACH
# 1    SKI-DOO    MX Z X-RS E-TEC 800R        NACH
# 2    SKI-DOO     MX Z X E-TEC 600 HO        NACH
# 3    SKI-DOO       MX Z X E-TEC 800R        NACH
# 4    SKI-DOO       MX Z X 4-TEC 1200        NACH
# ..       ...                     ...         ...
# 130  SKI-DOO       MX Z X E-TEC 600R        NACH
# 131  SKI-DOO    MX Z X-RS E-TEC 600R        NACH
# 132  SKI-DOO      MX Z Sport 600 EFI        NACH
# 133  SKI-DOO     MX Z Neo 600 EFI-40        NACH
# 134  SKI-DOO    MX Z Neo+ 600 EFI-55        NACH
#
#                        Vendor Name Position         MPN AD LIST NUMBER  Year
# 0    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-80001K        1121026  2015
# 1    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-80001K        1121026  2015
# 2    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-80001K        1121026  2015
# 3    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-80001K        1121026  2015
# 4    NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-80001K        1121026  2015
# ..                             ...      ...         ...            ...   ...
# 130  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-80001K        1121026  2019
# 131  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-80001K        1121026  2019
# 132  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-80001K        1121026  2019
# 133  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-80001K        1121026  2019
# 134  NACHMAN INTERNATIONAL CO. LTD      SKI  LS8-80001K        1121026  2019
#
# [135 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\33.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['ARCTIC CAT'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['FRONT TRACK'],
    
    'MPN': ['LS4-11000F'],
    
    'AD LIST NUMBER': ['1121001'],
    
    
}


#list all models
list_models = [

'Riot 8000 1.6in.',
'Riot 8000 1.35in.',
'Riot 8000 ATAC 1.6in.',
'Riot 8000 ATAC',
'Riot 8000',
'ZR 6000 El Tigre',
'ZR 6000 El Tigre ES',
'ZR 6000 RR',
'ZR 6000 LXR 129',
'ZR 6000 Sno Pro 129',
'ZR 6000 Limited 129',
'ZR 6000 Tucker Hibbert RR',
'ZR 6000 LXR 137',
'ZR 6000 Sno Pro 137',
'ZR 6000 Limited 137',
'ZR 6000 LXR ES 129',
'ZR 6000 LXR ES 137',
'ZR 6000 Sno Pro ES 129',
'ZR 6000 Sno Pro ES 137',
'ZR 6000 Limited ES 129',
'ZR 6000 Limited ES 137',
'ZR 6000 El Tigre ES 129',
'ZR 6000 El Tigre ES 137',
'ZR 6000 RR ES 129',
'ZR 6000 RR ES 137',
'ZR 6000 RS',
'ZR 6000 R XC 129',
'ZR 6000 ES 129',
'ZR 6000 ES 137',
'ZR 6000 Limited ES 129 iACT',
'ZR 6000 Limited ES 137 iACT',
'ZR 6000 R XC',
'ZR 6000 Limited ES ATAC 137',
'ZR 6000',
'ZR 6000 R-XC',
'ZR 6000 R-XC ES',
'ZR 8000 Limited 129',
'ZR 8000 Sno Pro 129',
'ZR 8000 LXR 129',
'ZR 8000 RR',
'ZR 8000 El Tigre',
'ZR 8000 LXR 137',
'ZR 8000 Sno Pro 137',
'ZR 8000 Limited 137',
'ZR 8000 LXR ES 129',
'ZR 8000 LXR ES 137',
'ZR 8000 Sno Pro ES 129',
'ZR 8000 Sno Pro ES 137',
'ZR 8000 Limited ES 129',
'ZR 8000 Limited ES 137',
'ZR 8000 El Tigre ES 129',
'ZR 8000 El Tigre ES 137',
'ZR 8000 RR ES 137',
'ZR 8000 RR ES 129',
'ZR 8000 Sno Pro ES 129 Early Build',
'ZR 8000 Sno Pro ES 137 Early Build',
'ZR 8000 ES 129',
'ZR 8000 ES 137',
'ZR 8000 Limited ES 137 iACT',
'ZR 8000 Limited ES 129 iACT',
'ZR 8000 Limited ES ATAC 137',
'ZR 8000',
'ZR 8000 ATAC',
'Riot 6000',
'Riot 6000 1.35in.',
'Pantera 7000 Limited',
'Pantera 7000',
'Pantera 7000 XT Limited',
'Pantera 6000 ES',
'ProClimb M 800 HCR'


]

#Range of Years
years = list(range(2012, 2024))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#            Make                    Model Vendor Code  \
# 0    ARCTIC CAT         Riot 8000 1.6in.        NACH
# 1    ARCTIC CAT        Riot 8000 1.35in.        NACH
# 2    ARCTIC CAT    Riot 8000 ATAC 1.6in.        NACH
# 3    ARCTIC CAT           Riot 8000 ATAC        NACH
# 4    ARCTIC CAT                Riot 8000        NACH
# ..          ...                      ...         ...
# 835  ARCTIC CAT     Pantera 7000 Limited        NACH
# 836  ARCTIC CAT             Pantera 7000        NACH
# 837  ARCTIC CAT  Pantera 7000 XT Limited        NACH
# 838  ARCTIC CAT          Pantera 6000 ES        NACH
# 839  ARCTIC CAT       ProClimb M 800 HCR        NACH
#
#                        Vendor Name     Position         MPN AD LIST NUMBER  \
# 0    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 1    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 2    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 3    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 4    NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# ..                             ...          ...         ...            ...
# 835  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 836  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 837  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 838  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
# 839  NACHMAN INTERNATIONAL CO. LTD  FRONT TRACK  LS4-11000F        1121001
#
#      Year
# 0    2012
# 1    2012
# 2    2012
# 3    2012
# 4    2012
# ..    ...
# 835  2023
# 836  2023
# 837  2023
# 838  2023
# 839  2023
#
# [840 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\34.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make': ['ARCTIC CAT'],
    'Model': ['All Model'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Position': ['REAR TRACK'],
    
    'MPN': ['LS4-11000R'],
    
    'AD LIST NUMBER': ['1121002'],
    
    
}


#list all models
list_models = [

'ZR 6000 El Tigre',
'ZR 6000 El Tigre ES',
'ZR 6000 RR',
'ZR 6000 LXR 129',
'ZR 6000 Sno Pro 129',
'ZR 6000 Limited 129',
'ZR 6000 Tucker Hibbert RR',
'ZR 6000 LXR 137',
'ZR 6000 Sno Pro 137',
'ZR 6000 Limited 137',
'ZR 6000 LXR ES 129',
'ZR 6000 LXR ES 137',
'ZR 6000 Sno Pro ES 129',
'ZR 6000 Sno Pro ES 137',
'ZR 6000 Limited ES 129',
'ZR 6000 Limited ES 137',
'ZR 6000 El Tigre ES 129',
'ZR 6000 El Tigre ES 137',
'ZR 6000 RR ES 129',
'ZR 6000 RR ES 137',
'ZR 6000 RS',
'ZR 6000 R XC 129',
'ZR 6000 ES 129',
'ZR 6000 ES 137',
'ZR 6000 Limited ES 129 iACT',
'ZR 6000 Limited ES 137 iACT',
'ZR 6000 R XC',
'ZR 6000 Limited ES ATAC 137',
'ZR 6000',
'ZR 6000 R-XC',
'ZR 6000 R-XC ES',
'ZR 8000 Limited 129',
'ZR 8000 Sno Pro 129',
'ZR 8000 LXR 129',
'ZR 8000 RR',
'ZR 8000 El Tigre',
'ZR 8000 LXR 137',
'ZR 8000 Sno Pro 137',
'ZR 8000 Limited 137',
'ZR 8000 LXR ES 129',
'ZR 8000 LXR ES 137',
'ZR 8000 Sno Pro ES 129',
'ZR 8000 Sno Pro ES 137',
'ZR 8000 Limited ES 129',
'ZR 8000 Limited ES 137',
'ZR 8000 El Tigre ES 129',
'ZR 8000 El Tigre ES 137',
'ZR 8000 RR ES 137',
'ZR 8000 RR ES 129',
'ZR 8000 Sno Pro ES 129 Early Build',
'ZR 8000 Sno Pro ES 137 Early Build',
'ZR 8000 ES 129',
'ZR 8000 ES 137',
'ZR 8000 Limited ES 137 iACT',
'ZR 8000 Limited ES 129 iACT',
'ZR 8000 Limited ES ATAC 137',
'ZR 8000',
'ZR 8000 ATAC'

]

#Range of Years
years = list(range(2016, 2024))

#Functions/Syntax to generate the Dataframe for each model

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model,data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
#Concatenate all DF's created
final_df = pd.concat(dfs, ignore_index=True)

#Display
final_df
# Out:
#            Make                        Model Vendor Code  \
# 0    ARCTIC CAT             ZR 6000 El Tigre        NACH
# 1    ARCTIC CAT          ZR 6000 El Tigre ES        NACH
# 2    ARCTIC CAT                   ZR 6000 RR        NACH
# 3    ARCTIC CAT              ZR 6000 LXR 129        NACH
# 4    ARCTIC CAT          ZR 6000 Sno Pro 129        NACH
# ..          ...                          ...         ...
# 459  ARCTIC CAT  ZR 8000 Limited ES 137 iACT        NACH
# 460  ARCTIC CAT  ZR 8000 Limited ES 129 iACT        NACH
# 461  ARCTIC CAT  ZR 8000 Limited ES ATAC 137        NACH
# 462  ARCTIC CAT                      ZR 8000        NACH
# 463  ARCTIC CAT                 ZR 8000 ATAC        NACH
#
#                        Vendor Name    Position         MPN AD LIST NUMBER  \
# 0    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-11000R        1121002
# 1    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-11000R        1121002
# 2    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-11000R        1121002
# 3    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-11000R        1121002
# 4    NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-11000R        1121002
# ..                             ...         ...         ...            ...
# 459  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-11000R        1121002
# 460  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-11000R        1121002
# 461  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-11000R        1121002
# 462  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-11000R        1121002
# 463  NACHMAN INTERNATIONAL CO. LTD  REAR TRACK  LS4-11000R        1121002
#
#      Year
# 0    2016
# 1    2016
# 2    2016
# 3    2016
# 4    2016
# ..    ...
# 459  2023
# 460  2023
# 461  2023
# 462  2023
# 463  2023
#
# [464 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SPI & LEN\SPI\Merge\35.csv"
final_df.to_csv(file_path, index = False)
